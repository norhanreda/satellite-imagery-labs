# %% [markdown]
# ## Students Information
#
# Please enter the names and IDs of the two students below:
#
# 1. **Name**: [Norhan Reda Abdelwahed Ahmed]
#    **ID**: `9203639`
#
# 2. **Name**: [Hoda Gamal Hamouda Ismail]
#    **ID**: `9203673`
#
# 3. **Name**: [Samaa Hazem Mohamed Abdellatif]
#    **ID**: `9202660`
#
# 4. **Name**: [Shaza Mohamed AbdelRahman]
#    **ID**: `9161007`

# %% [markdown]
# ## Students Instructions
#
# This is your last graded lab assignment, as you put the work you have studied in the lectures in action, please take this opportunity to enhance your understanding of the concepts and hone your skills. As you work on your assignment, please keep the following instructions in mind:
#
# - Clearly state your personal information where indicated.
# - Be ready with your work before the time of the next discussion slot in the schedule.
# - Plagiarism will be met with penalties, refrain from copying any answers to make the most out of the assignment. If any signs of plagiarism are detected, actions will be taken.
# - It is acceptable to share the workload of the assignment bearing the discussion in mind.
# - Feel free to [reach out](mailto:cmpsy27@gmail.com) if there were any ambiguities or post on the classroom.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this assignment. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed assignments and wish you the best of luck!

# %% [markdown]
# ## Installation Instructions
#
# In this lab assignment, we require additional Python libraries for machine learning (ML) and deep learning (DL) algorithms and frameworks. To fulfill these requirements, we need to install Pytorch.
# 1. Install Pytorch \
# PyTorch is a versatile and powerful machine learning library for Python, known for its flexibility and ease of use in research and production. It supports various deep learning operations and models, including convolutional and recurrent neural networks. For Windows users, the installation also requires ensuring that CUDA, provided by NVIDIA, is compatible to enable GPU acceleration. This enhances performance significantly, particularly in training large neural networks.\
# For windows installation with GPU support you can [check out this link](https://pytorch.org/get-started/locally/) which is the source for the command below and please know that support for GPU is done for windows so you can also check out [previous versions](https://pytorch.org/get-started/previous-versions/), you could use CPU on windows smoothly, use linux or resort to [WSL](https://www.youtube.com/watch?v=R4m8YEixidI).
#
# ```bash
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# ```
# ```bash
# conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# ```

# %% [markdown]
# > **Note:** You are allowed to install any other necessary libraries you deem useful for solving the lab. Please ensure that any additional libraries are compatible with the assignment requirements and are properly documented in your submission.

# %% [markdown]
# ## U-Net
#
# U-Net is a convolutional neural network designed specifically for biomedical image segmentation. First introduced in a 2015 paper by Olaf Ronneberger, Philipp Fischer, and Thomas Brox, its architecture is notably shaped like the letter "U", which inspired its name. This structure comprises a contracting path to capture context and a symmetrically expanding path that aids in precise localization, making it particularly adept at leveraging small datasets to achieve highly accurate segmentations. U-Net's ability to accurately segment various tissues and medical conditions has made it a staple in medical imaging and has spurred adaptations for broader image analysis applications. Its success in the medical domain demonstrates its potential for high-impact applications in other fields requiring detailed image segmentation.
#
# U-Net's robust architecture has found significant applications in the field of satellite imaging as well. The ability of U-Net to effectively handle multi-scale and high-resolution images makes it particularly suitable for satellite image analysis. In satellite imaging, U-Net is commonly used for tasks such as land cover classification, road detection, and building segmentation. Its structure allows for precise segmentation of complex objects from high-resolution satellite imagery, even with relatively limited labeled datasets. This capability is crucial in environmental monitoring, urban planning, and disaster management, where accurate and detailed image analysis is required. The adaptability and efficiency of U-Net in handling spatial hierarchies and various textures present in satellite images highlight its versatility and effectiveness beyond its initial medical context.

# %% [markdown]
# ### U-Net Architecture
#
# ![U-Net Architecture](unet.jpg)

# %% [markdown]
# ### Detailed Overview of Functions in `utilities.py`
#
# The `utilities.py` file contains multiple functions to support image processing, data manipulation, and neural network training:
#
# - **`generate_random_data(height, width, count)`**:
#   - Generates random images and masks.
#
# - **`generate_img_and_mask(height, width)`**:
#   - Generates a single image and corresponding mask.
#
# - **`add_square(img, mask)`**:
#   - Adds a square to an image and updates the mask.
#
# - **`add_filled_square(img, mask)`**:
#   - Adds a filled square to an image and updates the mask.
#
# - **`logical_and(mask1, mask2)`**:
#   - Performs logical 'AND' operation between two masks.
#
# - **`add_mesh_square(img, mask)`**:
#   - Adds a mesh-patterned square to an image and updates the mask.
#
# - **`add_triangle(img, mask)`**:
#   - Adds a triangle to an image and updates the mask.
#
# - **`add_circle(img, mask)`**:
#   - Adds a circle to an image and updates the mask.
#
# - **`add_plus(img, mask)`**:
#   - Adds a plus sign to an image and updates the mask.
#
# - **`get_random_location(shape, zoom)`**:
#   - Gets a random location within an image shape.
#
# - **`plot_img_array(img_array, n_col)`**:
#   - Plots an array of images.
#
# - **`plot_side_by_side(img_arrays)`**:
#   - Plots images side by side for comparison.
#
# - **`plot_errors(train_losses, val_losses)`**:
#   - Plots training and validation loss errors.
#
# - **`masks_to_colorimg(masks)`**:
#   - Converts masks to colored images.
#
# - **`generate_images_and_masks_then_plot()`**:
#   - Generates images and masks and plots them.
#
# - **`reverse_transform(transform)`**:
#   - Reverses a transformation applied to an image.
#
# - **`get_data_loaders(train_dir, valid_dir, batch_size)`**:
#   - Gets data loaders for training and validation datasets.
#
# - **`dice_loss(inputs, targets, smooth)`**:
#   - Calculates Dice loss for model evaluation.
#
# - **`calc_loss(pred, target, metrics)`**:
#   - Calculates loss and updates metrics.
#
# - **`print_metrics(metrics, epoch_samples, phase)`**:
#   - Prints metrics for training or validation phases.
#
# - **`train_model(model, dataloaders, criterion, optimizer, num_epochs)`**:
#   - Trains a model given data loaders and training parameters.
#
# - **`run(model)`**:
#   - Runs a full model training and evaluation session.
#
# - **`__init__`, `__len__`, `__getitem__`**:
#   - Standard class methods used in Python classes, typically for data handling or model initialization.
#
# These functions collectively facilitate the full lifecycle of processing, training, and evaluating neural network models, particularly focusing on image-related tasks.

# %% [markdown]
# The primary objective of this assignment is to develop a neural network model capable of performing accurate image segmentation. Image segmentation involves dividing an image into segments that represent different objects or regions, which is crucial in various applications such as medical imaging, autonomous driving, and satellite image analysis.
#
# #### Image and Mask Generation
# In this assignment, synthetic images along with corresponding segmentation masks are generated to train and evaluate the segmentation model. Each image typically includes multiple geometric shapes placed randomly. These shapes can include simple forms such as circles, squares, and triangles, or more complex designs.
#
# #### Masks and Their Role in Segmentation
# - **Mask Generation**: Alongside each synthetic image, a mask is generated where each shape in the image has a corresponding segment in the mask. Each segment in the mask is represented by a unique color or grayscale intensity, where each intensity level corresponds to a different class (shape).
# - **Function of the Mask**: The mask serves as a "ground truth" for training the segmentation model. The model learns to predict these masks from the input images. Essentially, the task of the model is to map the input image to its corresponding output mask, segmenting the shapes it has learned during training.
# - **Learning Process**: During training, the model adjusts its parameters to minimize the difference between its predicted masks and the ground truth masks. This process involves optimizing a loss function, typically using backpropagation.

# %% [markdown]
# ## Requirement - U-Net Application
# - **Implement or Use U-Net**:
#   - **Option 1: Implementation** - Students are encouraged to implement the U-Net architecture from scratch, including defining all the layers and connections based on the standard specifications found in the literature.
#   - **Option 2: Use Pre-existing Implementation** - Students may also opt to use an existing implementation of U-Net. This can include adapting an open-source model available in frameworks like PyTorch.
#
# - **Integration with `utilities.py`**:
#   - The U-Net model, whether self-implemented or pre-existing, must be integrated with the `utilities.py` script provided. This integration is essential for processing data, training the model, and evaluating its performance efficiently.
#   - The model should effectively process input images and produce accurate segmentation masks as output, corresponding to the different segments of the input images.
#   - **You can make any necessary modifications including writing your own training loop for example**.

# %%
# import libraries here
import torch
import torch.nn as nn
from torchvision import models
import utilities

# %%
class UNet(nn.Module):
    def __init__(self, n_classes):
        super(UNet, self).__init__()
        # TODO: Define needed layers, use n_class variable in the last layer.


        # Define the encoder layers
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU()
        self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv5 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.relu5 = nn.ReLU()
        self.conv6 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.relu6 = nn.ReLU()
        self.maxpool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv7 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.relu7 = nn.ReLU()
        self.conv8 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.relu8 = nn.ReLU()

        # Define the decoder layers
        self.upconv1 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.conv9 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.relu9 = nn.ReLU()
        self.conv10 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.relu10 = nn.ReLU()

        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.conv11 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.relu11 = nn.ReLU()
        self.conv12 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.relu12 = nn.ReLU()

        self.upconv3 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv13 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.relu13 = nn.ReLU()
        self.conv14 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.relu14 = nn.ReLU()

        # Define the output layer
        self.conv15 = nn.Conv2d(64, n_classes, kernel_size=1)

    def forward(self, x):
        # Encoder
        out = self.conv1(x)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.relu2(out)
        out1 = out
        out = self.maxpool1(out)

        out = self.conv3(out)
        out = self.relu3(out)
        out = self.conv4(out)
        out = self.relu4(out)
        out2 = out
        out = self.maxpool2(out)

        out = self.conv5(out)
        out = self.relu5(out)
        out = self.conv6(out)
        out = self.relu6(out)
        out3 = out
        out = self.maxpool3(out)

        # Base convolutional layers
        out = self.conv7(out)
        out = self.relu7(out)
        out = self.conv8(out)
        out = self.relu8(out)

        # Decoder
        out = self.upconv1(out)
        out = torch.cat((out, out3), dim=1)
        out = self.conv9(out)
        out = self.relu9(out)
        out = self.conv10(out)
        out = self.relu10(out)

        out = self.upconv2(out)
        out = torch.cat((out, out2), dim=1)
        out = self.conv11(out)
        out = self.relu11(out)
        out = self.conv12(out)
        out = self.relu12(out)

        out = self.upconv3(out)
        out = torch.cat((out, out1), dim=1)
        out = self.conv13(out)
        out = self.relu13(out)
        out = self.conv14(out)
        out = self.relu14(out)

        out = self.conv15(out)

        return out

# %%
import utilities

# %%
utilities.run(UNet)
# Out:
# Epoch 0/19
# ----------
# LR 0.0001
# train: jaccard: 0.004933, bce: 0.672989, dice: 0.990099, loss: 0.831544
# val: jaccard: 0.004506, bce: 0.660546, dice: 0.990945, loss: 0.825745
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.0001
# train: jaccard: 0.004949, bce: 0.652793, dice: 0.990062, loss: 0.821427
# val: jaccard: 0.004523, bce: 0.638432, dice: 0.990904, loss: 0.814668
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.0001
# train: jaccard: 0.004971, bce: 0.626156, dice: 0.990012, loss: 0.808084
# val: jaccard: 0.004553, bce: 0.601617, dice: 0.990843, loss: 0.796230
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.0001
# train: jaccard: 0.004993, bce: 0.580915, dice: 0.989963, loss: 0.785439
# val: jaccard: 0.004570, bce: 0.537676, dice: 0.990813, loss: 0.764245
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.0001
# train: jaccard: 0.004975, bce: 0.495471, dice: 0.990011, loss: 0.742741
# val: jaccard: 0.004458, bce: 0.396701, dice: 0.991089, loss: 0.693895
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.0001
# train: jaccard: 0.004399, bce: 0.280423, dice: 0.991396, loss: 0.635909
# val: jaccard: 0.002333, bce: 0.068532, dice: 0.995592, loss: 0.532062
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.0001
# train: jaccard: 0.000771, bce: 0.077115, dice: 0.995736, loss: 0.536425
# val: jaccard: 0.000000, bce: 0.112162, dice: 0.993755, loss: 0.552958
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.0001
# train: jaccard: 0.000000, bce: 0.110201, dice: 0.994252, loss: 0.552227
# val: jaccard: 0.000023, bce: 0.061053, dice: 0.995102, loss: 0.528078
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.0001
# train: jaccard: 0.000830, bce: 0.051190, dice: 0.995188, loss: 0.523189
# val: jaccard: 0.003958, bce: 0.035348, dice: 0.991691, loss: 0.513519
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.0001
# train: jaccard: 0.006631, bce: 0.040856, dice: 0.987372, loss: 0.514114
# val: jaccard: 0.008914, bce: 0.043544, dice: 0.983133, loss: 0.513339
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.0001
# train: jaccard: 0.010929, bce: 0.043035, dice: 0.979483, loss: 0.511259
# val: jaccard: 0.012511, bce: 0.034828, dice: 0.976312, loss: 0.505570
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.0001
# train: jaccard: 0.014842, bce: 0.032587, dice: 0.972070, loss: 0.502329
# val: jaccard: 0.017045, bce: 0.026022, dice: 0.968084, loss: 0.497053
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.0001
# train: jaccard: 0.021030, bce: 0.026615, dice: 0.960824, loss: 0.493719
# val: jaccard: 0.027558, bce: 0.023025, dice: 0.949785, loss: 0.486405
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.0001
# train: jaccard: 0.034464, bce: 0.024085, dice: 0.937365, loss: 0.480725
# val: jaccard: 0.044340, bce: 0.021221, dice: 0.920079, loss: 0.470650
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.0001
# train: jaccard: 0.052697, bce: 0.022219, dice: 0.904749, loss: 0.463484
# val: jaccard: 0.064225, bce: 0.019399, dice: 0.883434, loss: 0.451417
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.0001
# train: jaccard: 0.072143, bce: 0.020537, dice: 0.869550, loss: 0.445043
# val: jaccard: 0.083240, bce: 0.018118, dice: 0.849654, loss: 0.433886
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.0001
# train: jaccard: 0.089325, bce: 0.019562, dice: 0.840098, loss: 0.429830
# val: jaccard: 0.099406, bce: 0.017500, dice: 0.822574, loss: 0.420037
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.0001
# train: jaccard: 0.104539, bce: 0.019043, dice: 0.815823, loss: 0.417433
# val: jaccard: 0.114178, bce: 0.017156, dice: 0.801049, loss: 0.409103
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.0001
# train: jaccard: 0.118075, bce: 0.018767, dice: 0.796642, loss: 0.407704
# val: jaccard: 0.127608, bce: 0.016810, dice: 0.783325, loss: 0.400068
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.0001
# train: jaccard: 0.130284, bce: 0.018406, dice: 0.780866, loss: 0.399636
# val: jaccard: 0.138401, bce: 0.016686, dice: 0.769371, loss: 0.393029
# saving best model
# 0m 2s
# Best val loss: 0.393029
# test: jaccard: 0.141817, bce: 0.021361, dice: 0.773455, loss: 0.397408
# (3, 6, 192, 192)

# %%
utilities.run(UNet,learn_rate=1e-3)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# train: jaccard: 0.004941, bce: 0.628898, dice: 0.990145, loss: 0.809521
# val: jaccard: 0.004444, bce: 0.292488, dice: 0.993973, loss: 0.643230
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.001
# train: jaccard: 0.003856, bce: 0.211967, dice: 0.991472, loss: 0.601720
# val: jaccard: 0.010137, bce: 0.094703, dice: 0.979173, loss: 0.536938
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.001
# train: jaccard: 0.030752, bce: 0.050445, dice: 0.941815, loss: 0.496130
# val: jaccard: 0.075103, bce: 0.016617, dice: 0.863994, loss: 0.440305
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.001
# train: jaccard: 0.087544, bce: 0.019014, dice: 0.842634, loss: 0.430824
# val: jaccard: 0.104141, bce: 0.018211, dice: 0.815902, loss: 0.417056
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.001
# train: jaccard: 0.106134, bce: 0.020485, dice: 0.812524, loss: 0.416504
# val: jaccard: 0.114509, bce: 0.018349, dice: 0.797984, loss: 0.408166
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.001
# train: jaccard: 0.117996, bce: 0.019751, dice: 0.792532, loss: 0.406142
# val: jaccard: 0.127077, bce: 0.017124, dice: 0.776756, loss: 0.396940
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.001
# train: jaccard: 0.128520, bce: 0.019107, dice: 0.775337, loss: 0.397222
# val: jaccard: 0.134126, bce: 0.018082, dice: 0.763564, loss: 0.390823
# saving best model
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.001
# train: jaccard: 0.143750, bce: 0.018900, dice: 0.752387, loss: 0.385644
# val: jaccard: 0.162451, bce: 0.016276, dice: 0.728473, loss: 0.372374
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.001
# train: jaccard: 0.185423, bce: 0.020044, dice: 0.705603, loss: 0.362824
# val: jaccard: 0.210123, bce: 0.021533, dice: 0.671755, loss: 0.346644
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.001
# train: jaccard: 0.218635, bce: 0.025091, dice: 0.663880, loss: 0.344485
# val: jaccard: 0.235898, bce: 0.024355, dice: 0.630526, loss: 0.327441
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.001
# train: jaccard: 0.255681, bce: 0.024509, dice: 0.618879, loss: 0.321694
# val: jaccard: 0.276634, bce: 0.020504, dice: 0.591582, loss: 0.306043
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.001
# train: jaccard: 0.305897, bce: 0.022902, dice: 0.562313, loss: 0.292607
# val: jaccard: 0.338964, bce: 0.023771, dice: 0.517345, loss: 0.270558
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.001
# train: jaccard: 0.343256, bce: 0.026414, dice: 0.513113, loss: 0.269763
# val: jaccard: 0.325820, bce: 0.024175, dice: 0.516351, loss: 0.270263
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.001
# train: jaccard: 0.343815, bce: 0.026830, dice: 0.508996, loss: 0.267913
# val: jaccard: 0.344993, bce: 0.024323, dice: 0.476337, loss: 0.250330
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.001
# train: jaccard: 0.366486, bce: 0.024109, dice: 0.472261, loss: 0.248185
# val: jaccard: 0.378857, bce: 0.020310, dice: 0.471246, loss: 0.245778
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.001
# train: jaccard: 0.394632, bce: 0.020870, dice: 0.451270, loss: 0.236070
# val: jaccard: 0.364773, bce: 0.018958, dice: 0.450184, loss: 0.234571
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.001
# train: jaccard: 0.393168, bce: 0.020561, dice: 0.443126, loss: 0.231844
# val: jaccard: 0.395243, bce: 0.020335, dice: 0.423007, loss: 0.221671
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.001
# train: jaccard: 0.415197, bce: 0.021844, dice: 0.419095, loss: 0.220469
# val: jaccard: 0.402997, bce: 0.021426, dice: 0.423131, loss: 0.222279
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.001
# train: jaccard: 0.429792, bce: 0.021107, dice: 0.406556, loss: 0.213831
# val: jaccard: 0.421718, bce: 0.018772, dice: 0.400552, loss: 0.209662
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.001
# train: jaccard: 0.438973, bce: 0.019741, dice: 0.394522, loss: 0.207131
# val: jaccard: 0.426221, bce: 0.019508, dice: 0.389913, loss: 0.204711
# saving best model
# 0m 2s
# Best val loss: 0.204711
# test: jaccard: 0.424843, bce: 0.021924, dice: 0.368124, loss: 0.195024
# (3, 6, 192, 192)

# %%
utilities.run(UNet,learn_rate=1e-2)
# Out:
# Epoch 0/19
# ----------
# LR 0.01
# train: jaccard: 0.002653, bce: 148.804466, dice: 0.991858, loss: 74.898159
# val: jaccard: 0.004959, bce: 679.536377, dice: 0.990635, loss: 340.263519
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.01
# train: jaccard: 0.004818, bce: 1928.536881, dice: 0.992541, loss: 964.764732
# val: jaccard: 0.004790, bce: 95.870903, dice: 0.991788, loss: 48.431347
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.01
# train: jaccard: 0.004442, bce: 950.163435, dice: 0.991477, loss: 475.577452
# val: jaccard: 0.000000, bce: 702.709473, dice: 0.992427, loss: 351.850952
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.01
# train: jaccard: 0.003839, bce: 202.888845, dice: 0.990531, loss: 101.939690
# val: jaccard: 0.004500, bce: 0.606696, dice: 0.990983, loss: 0.798839
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.01
# train: jaccard: 0.004937, bce: 0.600621, dice: 0.990120, loss: 0.795371
# val: jaccard: 0.004506, bce: 0.590030, dice: 0.990984, loss: 0.790507
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.01
# train: jaccard: 0.004944, bce: 0.584207, dice: 0.990121, loss: 0.787164
# val: jaccard: 0.004513, bce: 0.574170, dice: 0.990984, loss: 0.782577
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.01
# train: jaccard: 0.005029, bce: 0.818798, dice: 0.989922, loss: 0.904360
# val: jaccard: 0.004520, bce: 0.558257, dice: 0.990985, loss: 0.774621
# saving best model
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.01
# train: jaccard: 0.004960, bce: 0.552472, dice: 0.990124, loss: 0.771298
# val: jaccard: 0.004526, bce: 0.542528, dice: 0.990986, loss: 0.766757
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.01
# train: jaccard: 0.004967, bce: 0.536844, dice: 0.990125, loss: 0.763485
# val: jaccard: 0.004531, bce: 0.526980, dice: 0.990987, loss: 0.758984
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.01
# train: jaccard: 0.004973, bce: 0.521088, dice: 0.990127, loss: 0.755607
# val: jaccard: 0.004535, bce: 0.510443, dice: 0.990988, loss: 0.750716
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.01
# train: jaccard: 0.004977, bce: 0.504129, dice: 0.990129, loss: 0.747129
# val: jaccard: 0.004537, bce: 0.492957, dice: 0.990990, loss: 0.741973
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.01
# train: jaccard: 0.004979, bce: 0.486347, dice: 0.990131, loss: 0.738239
# val: jaccard: 0.004537, bce: 0.474581, dice: 0.990992, loss: 0.732787
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.01
# train: jaccard: 0.004977, bce: 0.467600, dice: 0.990134, loss: 0.728867
# val: jaccard: 0.004534, bce: 0.455110, dice: 0.990994, loss: 0.723052
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.01
# train: jaccard: 0.004971, bce: 0.447699, dice: 0.990137, loss: 0.718918
# val: jaccard: 0.004529, bce: 0.434407, dice: 0.990997, loss: 0.712702
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.01
# train: jaccard: 0.004962, bce: 0.426556, dice: 0.990141, loss: 0.708349
# val: jaccard: 0.004520, bce: 0.412457, dice: 0.991000, loss: 0.701729
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.01
# train: jaccard: 0.004948, bce: 0.404200, dice: 0.990147, loss: 0.697173
# val: jaccard: 0.004510, bce: 0.389405, dice: 0.991004, loss: 0.690204
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.01
# train: jaccard: 0.004933, bce: 0.380878, dice: 0.990153, loss: 0.685516
# val: jaccard: 0.004498, bce: 0.365546, dice: 0.991008, loss: 0.678277
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.01
# train: jaccard: 0.004914, bce: 0.356806, dice: 0.990160, loss: 0.673483
# val: jaccard: 0.004484, bce: 0.341076, dice: 0.991014, loss: 0.666045
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.01
# train: jaccard: 0.004893, bce: 0.332257, dice: 0.990169, loss: 0.661213
# val: jaccard: 0.004468, bce: 0.316361, dice: 0.991021, loss: 0.653691
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.01
# train: jaccard: 0.004869, bce: 0.307621, dice: 0.990180, loss: 0.648900
# val: jaccard: 0.004450, bce: 0.291791, dice: 0.991028, loss: 0.641410
# saving best model
# 0m 2s
# Best val loss: 0.641410
# test: jaccard: 0.005435, bce: 0.293239, dice: 0.988864, loss: 0.641052
# (3, 6, 192, 192)

# %%
utilities.run(UNet,learn_rate=1e-1)
# Out:
# Epoch 0/19
# ----------
# LR 0.1
# train: jaccard: 0.002569, bce: 100905062625902592.000000, dice: 0.991045, loss: 50452531312951296.000000
# val: jaccard: 0.004483, bce: 0.662020, dice: 0.990980, loss: 0.826500
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.1
# train: jaccard: 0.004949, bce: 524099849494528.187500, dice: 0.990061, loss: 262049924747264.187500
# val: jaccard: 0.004469, bce: 0.417113, dice: 0.991002, loss: 0.704057
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.1
# train: jaccard: 0.004896, bce: 0.375045, dice: 0.990157, loss: 0.682601
# val: jaccard: 0.004449, bce: 0.309656, dice: 0.991022, loss: 0.650339
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.1
# train: jaccard: 0.004870, bce: 0.278088, dice: 0.990190, loss: 0.634139
# val: jaccard: 0.004423, bce: 0.229591, dice: 0.991050, loss: 0.610320
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.1
# train: jaccard: 0.004837, bce: 0.207478, dice: 0.990235, loss: 0.598856
# val: jaccard: 0.004391, bce: 0.173149, dice: 0.991086, loss: 0.582118
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.1
# train: jaccard: 0.004796, bce: 0.158265, dice: 0.990292, loss: 0.574278
# val: jaccard: 0.004354, bce: 0.134352, dice: 0.991129, loss: 0.562740
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.1
# train: jaccard: 0.004748, bce: 0.124570, dice: 0.990357, loss: 0.557464
# val: jaccard: 0.004312, bce: 0.107826, dice: 0.991177, loss: 0.549501
# saving best model
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.1
# train: jaccard: 0.004697, bce: 0.101502, dice: 0.990428, loss: 0.545965
# val: jaccard: 0.004267, bce: 0.089548, dice: 0.991228, loss: 0.540388
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.1
# train: jaccard: 0.004641, bce: 0.085559, dice: 0.990506, loss: 0.538033
# val: jaccard: 0.004219, bce: 0.076748, dice: 0.991281, loss: 0.534014
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.1
# train: jaccard: 0.004585, bce: 0.074319, dice: 0.990581, loss: 0.532450
# val: jaccard: 0.004172, bce: 0.067599, dice: 0.991332, loss: 0.529466
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.1
# train: jaccard: 0.004530, bce: 0.066238, dice: 0.990655, loss: 0.528446
# val: jaccard: 0.004125, bce: 0.060908, dice: 0.991382, loss: 0.526145
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.1
# train: jaccard: 0.004474, bce: 0.060290, dice: 0.990728, loss: 0.525509
# val: jaccard: 0.004080, bce: 0.055897, dice: 0.991429, loss: 0.523663
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.1
# train: jaccard: 0.004423, bce: 0.055801, dice: 0.990793, loss: 0.523297
# val: jaccard: 0.004037, bce: 0.052057, dice: 0.991473, loss: 0.521765
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.1
# train: jaccard: 0.004373, bce: 0.052340, dice: 0.990855, loss: 0.521598
# val: jaccard: 0.003996, bce: 0.049048, dice: 0.991514, loss: 0.520281
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.1
# train: jaccard: 0.004326, bce: 0.049613, dice: 0.990914, loss: 0.520263
# val: jaccard: 0.003958, bce: 0.046639, dice: 0.991552, loss: 0.519096
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.1
# train: jaccard: 0.004282, bce: 0.047415, dice: 0.990967, loss: 0.519191
# val: jaccard: 0.003921, bce: 0.044675, dice: 0.991587, loss: 0.518131
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.1
# train: jaccard: 0.004240, bce: 0.045616, dice: 0.991018, loss: 0.518317
# val: jaccard: 0.003886, bce: 0.043043, dice: 0.991620, loss: 0.517331
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.1
# train: jaccard: 0.004199, bce: 0.044116, dice: 0.991065, loss: 0.517591
# val: jaccard: 0.003852, bce: 0.041667, dice: 0.991650, loss: 0.516658
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.1
# train: jaccard: 0.004161, bce: 0.042844, dice: 0.991108, loss: 0.516976
# val: jaccard: 0.003820, bce: 0.040491, dice: 0.991678, loss: 0.516085
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.1
# train: jaccard: 0.004125, bce: 0.041755, dice: 0.991149, loss: 0.516452
# val: jaccard: 0.003790, bce: 0.039474, dice: 0.991705, loss: 0.515590
# saving best model
# 0m 2s
# Best val loss: 0.515590
# test: jaccard: 0.004561, bce: 0.043809, dice: 0.990337, loss: 0.517073
# (3, 6, 192, 192)

# %%
utilities.run(UNet,stp_size=10)
# Out:
# Epoch 0/19
# ----------
# LR 0.0001
# train: jaccard: 0.004942, bce: 0.670321, dice: 0.990151, loss: 0.830236
# val: jaccard: 0.004521, bce: 0.656477, dice: 0.990982, loss: 0.823730
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.0001
# train: jaccard: 0.004965, bce: 0.645437, dice: 0.990097, loss: 0.817767
# val: jaccard: 0.004553, bce: 0.624146, dice: 0.990915, loss: 0.807530
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.0001
# train: jaccard: 0.004997, bce: 0.607725, dice: 0.990027, loss: 0.798876
# val: jaccard: 0.004575, bce: 0.575128, dice: 0.990866, loss: 0.782997
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.0001
# train: jaccard: 0.005009, bce: 0.546503, dice: 0.989992, loss: 0.768248
# val: jaccard: 0.004577, bce: 0.484609, dice: 0.990863, loss: 0.737736
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.0001
# train: jaccard: 0.004945, bce: 0.418495, dice: 0.990180, loss: 0.704337
# val: jaccard: 0.004355, bce: 0.260452, dice: 0.991623, loss: 0.626037
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.0001
# train: jaccard: 0.003620, bce: 0.142421, dice: 0.993236, loss: 0.567829
# val: jaccard: 0.000095, bce: 0.058129, dice: 0.996183, loss: 0.527156
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.0001
# train: jaccard: 0.000029, bce: 0.098306, dice: 0.994878, loss: 0.546592
# val: jaccard: 0.000000, bce: 0.096409, dice: 0.993850, loss: 0.545129
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.0001
# train: jaccard: 0.000027, bce: 0.080698, dice: 0.994737, loss: 0.537717
# val: jaccard: 0.000509, bce: 0.041662, dice: 0.995332, loss: 0.518497
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.0001
# train: jaccard: 0.003080, bce: 0.038811, dice: 0.992127, loss: 0.515469
# val: jaccard: 0.007854, bce: 0.034899, dice: 0.984887, loss: 0.509893
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 1e-05
# train: jaccard: 0.008553, bce: 0.037104, dice: 0.983820, loss: 0.510462
# val: jaccard: 0.008413, bce: 0.035448, dice: 0.983934, loss: 0.509691
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 1e-05
# train: jaccard: 0.009077, bce: 0.037294, dice: 0.982911, loss: 0.510103
# val: jaccard: 0.008813, bce: 0.035202, dice: 0.983242, loss: 0.509222
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 1e-05
# train: jaccard: 0.009438, bce: 0.036810, dice: 0.982265, loss: 0.509538
# val: jaccard: 0.009119, bce: 0.034407, dice: 0.982701, loss: 0.508554
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 1e-05
# train: jaccard: 0.009720, bce: 0.035898, dice: 0.981753, loss: 0.508826
# val: jaccard: 0.009370, bce: 0.033340, dice: 0.982250, loss: 0.507795
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 1e-05
# train: jaccard: 0.009946, bce: 0.034830, dice: 0.981324, loss: 0.508077
# val: jaccard: 0.009598, bce: 0.032251, dice: 0.981828, loss: 0.507040
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 1e-05
# train: jaccard: 0.010166, bce: 0.033802, dice: 0.980899, loss: 0.507350
# val: jaccard: 0.009835, bce: 0.031287, dice: 0.981384, loss: 0.506336
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 1e-05
# train: jaccard: 0.010410, bce: 0.032922, dice: 0.980433, loss: 0.506678
# val: jaccard: 0.010111, bce: 0.030498, dice: 0.980869, loss: 0.505684
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 1e-05
# train: jaccard: 0.010698, bce: 0.032213, dice: 0.979880, loss: 0.506046
# val: jaccard: 0.010461, bce: 0.029881, dice: 0.980225, loss: 0.505053
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 1e-05
# train: jaccard: 0.011091, bce: 0.031650, dice: 0.979164, loss: 0.505407
# val: jaccard: 0.010892, bce: 0.029400, dice: 0.979443, loss: 0.504422
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 1e-05
# train: jaccard: 0.011567, bce: 0.031202, dice: 0.978301, loss: 0.504752
# val: jaccard: 0.011413, bce: 0.029019, dice: 0.978508, loss: 0.503763
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.011927, bce: 0.030949, dice: 0.977656, loss: 0.504302
# val: jaccard: 0.011473, bce: 0.028988, dice: 0.978401, loss: 0.503694
# saving best model
# 0m 2s
# Best val loss: 0.503694
# test: jaccard: 0.015012, bce: 0.033024, dice: 0.973132, loss: 0.503078
# (3, 6, 192, 192)

# %%
utilities.run(UNet,stp_size=20)
# Out:
# Epoch 0/19
# ----------
# LR 0.0001
# train: jaccard: 0.004962, bce: 0.719294, dice: 0.990106, loss: 0.854700
# val: jaccard: 0.004547, bce: 0.703090, dice: 0.990898, loss: 0.846994
# saving best model
# 0m 3s
# Epoch 1/19
# ----------
# LR 0.0001
# train: jaccard: 0.005021, bce: 0.690704, dice: 0.989973, loss: 0.840339
# val: jaccard: 0.004608, bce: 0.668782, dice: 0.990763, loss: 0.829772
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.0001
# train: jaccard: 0.005082, bce: 0.653105, dice: 0.989832, loss: 0.821468
# val: jaccard: 0.004665, bce: 0.623152, dice: 0.990629, loss: 0.806890
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.0001
# train: jaccard: 0.005138, bce: 0.599404, dice: 0.989696, loss: 0.794550
# val: jaccard: 0.004709, bce: 0.549533, dice: 0.990504, loss: 0.770019
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.0001
# train: jaccard: 0.005145, bce: 0.498302, dice: 0.989621, loss: 0.743962
# val: jaccard: 0.004600, bce: 0.375789, dice: 0.990664, loss: 0.683227
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.0001
# train: jaccard: 0.004598, bce: 0.266482, dice: 0.991636, loss: 0.629059
# val: jaccard: 0.003415, bce: 0.110873, dice: 0.995840, loss: 0.553356
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.0001
# train: jaccard: 0.001527, bce: 0.105737, dice: 0.994945, loss: 0.550341
# val: jaccard: 0.000002, bce: 0.101385, dice: 0.994104, loss: 0.547744
# saving best model
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.0001
# train: jaccard: 0.000047, bce: 0.083471, dice: 0.994947, loss: 0.539209
# val: jaccard: 0.000720, bce: 0.041625, dice: 0.995679, loss: 0.518652
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.0001
# train: jaccard: 0.003825, bce: 0.040702, dice: 0.991904, loss: 0.516303
# val: jaccard: 0.007640, bce: 0.043957, dice: 0.985353, loss: 0.514655
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.0001
# train: jaccard: 0.009886, bce: 0.047368, dice: 0.981639, loss: 0.514504
# val: jaccard: 0.010870, bce: 0.041074, dice: 0.979151, loss: 0.510112
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.0001
# train: jaccard: 0.012574, bce: 0.036275, dice: 0.976555, loss: 0.506415
# val: jaccard: 0.012430, bce: 0.027375, dice: 0.976360, loss: 0.501867
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.0001
# train: jaccard: 0.014478, bce: 0.027556, dice: 0.972805, loss: 0.500180
# val: jaccard: 0.017871, bce: 0.024078, dice: 0.966993, loss: 0.495536
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.0001
# train: jaccard: 0.023208, bce: 0.025025, dice: 0.957370, loss: 0.491197
# val: jaccard: 0.030175, bce: 0.022548, dice: 0.944818, loss: 0.483683
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.0001
# train: jaccard: 0.036562, bce: 0.023325, dice: 0.932264, loss: 0.477794
# val: jaccard: 0.043670, bce: 0.020454, dice: 0.918284, loss: 0.469369
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.0001
# train: jaccard: 0.050006, bce: 0.021153, dice: 0.906265, loss: 0.463709
# val: jaccard: 0.056422, bce: 0.018650, dice: 0.894095, loss: 0.456372
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.0001
# train: jaccard: 0.062370, bce: 0.019761, dice: 0.883307, loss: 0.451534
# val: jaccard: 0.069723, bce: 0.017890, dice: 0.868335, loss: 0.443113
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.0001
# train: jaccard: 0.076957, bce: 0.019439, dice: 0.856231, loss: 0.437835
# val: jaccard: 0.084742, bce: 0.018195, dice: 0.840734, loss: 0.429464
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.0001
# train: jaccard: 0.093189, bce: 0.019329, dice: 0.830278, loss: 0.424803
# val: jaccard: 0.102673, bce: 0.016979, dice: 0.815076, loss: 0.416028
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.0001
# train: jaccard: 0.108694, bce: 0.018298, dice: 0.808875, loss: 0.413586
# val: jaccard: 0.115669, bce: 0.016596, dice: 0.796946, loss: 0.406771
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 1e-05
# train: jaccard: 0.116515, bce: 0.018214, dice: 0.797736, loss: 0.407975
# val: jaccard: 0.116728, bce: 0.016655, dice: 0.795323, loss: 0.405989
# saving best model
# 0m 2s
# Best val loss: 0.405989
# test: jaccard: 0.119294, bce: 0.021307, dice: 0.797160, loss: 0.409234
# (3, 6, 192, 192)

# %%
utilities.run(UNet,stp_size=30)
# Out:
# Epoch 0/19
# ----------
# LR 0.0001
# train: jaccard: 0.004991, bce: 0.708843, dice: 0.990090, loss: 0.849467
# val: jaccard: 0.004551, bce: 0.702421, dice: 0.990941, loss: 0.846681
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.0001
# train: jaccard: 0.005000, bce: 0.699097, dice: 0.990075, loss: 0.844586
# val: jaccard: 0.004556, bce: 0.692837, dice: 0.990941, loss: 0.841889
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.0001
# train: jaccard: 0.005002, bce: 0.687609, dice: 0.990084, loss: 0.838847
# val: jaccard: 0.004556, bce: 0.677408, dice: 0.990960, loss: 0.834184
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.0001
# train: jaccard: 0.005004, bce: 0.668329, dice: 0.990112, loss: 0.829220
# val: jaccard: 0.004555, bce: 0.649606, dice: 0.990997, loss: 0.820302
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.0001
# train: jaccard: 0.004990, bce: 0.631383, dice: 0.990191, loss: 0.810787
# val: jaccard: 0.004503, bce: 0.590082, dice: 0.991174, loss: 0.790628
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.0001
# train: jaccard: 0.004835, bce: 0.536344, dice: 0.990679, loss: 0.763512
# val: jaccard: 0.004081, bce: 0.391968, dice: 0.992655, loss: 0.692311
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.0001
# train: jaccard: 0.003652, bce: 0.246020, dice: 0.994252, loss: 0.620136
# val: jaccard: 0.000738, bce: 0.074672, dice: 0.996511, loss: 0.535592
# saving best model
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.0001
# train: jaccard: 0.000185, bce: 0.128648, dice: 0.995203, loss: 0.561926
# val: jaccard: 0.000000, bce: 0.134212, dice: 0.993912, loss: 0.564062
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.0001
# train: jaccard: 0.000014, bce: 0.107432, dice: 0.994968, loss: 0.551200
# val: jaccard: 0.000307, bce: 0.051140, dice: 0.996307, loss: 0.523724
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.0001
# train: jaccard: 0.001760, bce: 0.050577, dice: 0.995399, loss: 0.522988
# val: jaccard: 0.003818, bce: 0.054924, dice: 0.992827, loss: 0.523875
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.0001
# train: jaccard: 0.004918, bce: 0.057218, dice: 0.990939, loss: 0.524079
# val: jaccard: 0.004791, bce: 0.046981, dice: 0.990706, loss: 0.518843
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.0001
# train: jaccard: 0.004567, bce: 0.041575, dice: 0.990982, loss: 0.516279
# val: jaccard: 0.002758, bce: 0.033724, dice: 0.993276, loss: 0.513500
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.0001
# train: jaccard: 0.002755, bce: 0.035788, dice: 0.993077, loss: 0.514433
# val: jaccard: 0.003041, bce: 0.032165, dice: 0.992347, loss: 0.512256
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.0001
# train: jaccard: 0.004705, bce: 0.033408, dice: 0.989692, loss: 0.511550
# val: jaccard: 0.007398, bce: 0.030443, dice: 0.985114, loss: 0.507778
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.0001
# train: jaccard: 0.010065, bce: 0.033130, dice: 0.980423, loss: 0.506776
# val: jaccard: 0.012360, bce: 0.032537, dice: 0.975906, loss: 0.504222
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.0001
# train: jaccard: 0.014915, bce: 0.032885, dice: 0.971062, loss: 0.501974
# val: jaccard: 0.016770, bce: 0.028085, dice: 0.966905, loss: 0.497495
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.0001
# train: jaccard: 0.020369, bce: 0.027728, dice: 0.959626, loss: 0.493677
# val: jaccard: 0.024741, bce: 0.023804, dice: 0.950394, loss: 0.487099
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.0001
# train: jaccard: 0.031635, bce: 0.024402, dice: 0.935870, loss: 0.480136
# val: jaccard: 0.041043, bce: 0.021683, dice: 0.915207, loss: 0.468445
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.0001
# train: jaccard: 0.050223, bce: 0.022200, dice: 0.896100, loss: 0.459150
# val: jaccard: 0.060102, bce: 0.019235, dice: 0.874864, loss: 0.447049
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.0001
# train: jaccard: 0.068019, bce: 0.019989, dice: 0.861472, loss: 0.440730
# val: jaccard: 0.077055, bce: 0.018099, dice: 0.842391, loss: 0.430245
# saving best model
# 0m 2s
# Best val loss: 0.430245
# test: jaccard: 0.084418, bce: 0.022289, dice: 0.838747, loss: 0.430518
# (3, 6, 192, 192)

# %%
utilities.run(UNet,gma=0.1)
# Out:
# Epoch 0/19
# ----------
# LR 0.0001
# train: jaccard: 0.004983, bce: 0.697487, dice: 0.990103, loss: 0.843795
# val: jaccard: 0.004544, bce: 0.690057, dice: 0.990968, loss: 0.840513
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.0001
# train: jaccard: 0.004990, bce: 0.685805, dice: 0.990098, loss: 0.837952
# val: jaccard: 0.004539, bce: 0.678195, dice: 0.990985, loss: 0.834590
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.0001
# train: jaccard: 0.004982, bce: 0.671956, dice: 0.990131, loss: 0.831044
# val: jaccard: 0.004519, bce: 0.659119, dice: 0.991044, loss: 0.825082
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.0001
# train: jaccard: 0.004960, bce: 0.647309, dice: 0.990212, loss: 0.818761
# val: jaccard: 0.004475, bce: 0.622199, dice: 0.991176, loss: 0.806687
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.0001
# train: jaccard: 0.004907, bce: 0.595025, dice: 0.990406, loss: 0.792715
# val: jaccard: 0.004370, bce: 0.529069, dice: 0.991532, loss: 0.760301
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.0001
# train: jaccard: 0.004738, bce: 0.439762, dice: 0.991274, loss: 0.715518
# val: jaccard: 0.003968, bce: 0.229858, dice: 0.994017, loss: 0.611937
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.0001
# train: jaccard: 0.003172, bce: 0.133564, dice: 0.994923, loss: 0.564243
# val: jaccard: 0.000008, bce: 0.110279, dice: 0.994394, loss: 0.552336
# saving best model
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.0001
# train: jaccard: 0.000003, bce: 0.139154, dice: 0.994058, loss: 0.566606
# val: jaccard: 0.000001, bce: 0.099430, dice: 0.994129, loss: 0.546780
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.0001
# train: jaccard: 0.000270, bce: 0.075838, dice: 0.995121, loss: 0.535479
# val: jaccard: 0.001849, bce: 0.046101, dice: 0.995257, loss: 0.520679
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.0001
# train: jaccard: 0.003596, bce: 0.051929, dice: 0.993227, loss: 0.522578
# val: jaccard: 0.004765, bce: 0.054243, dice: 0.990550, loss: 0.522396
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.0001
# train: jaccard: 0.005710, bce: 0.050938, dice: 0.988734, loss: 0.519836
# val: jaccard: 0.005617, bce: 0.039393, dice: 0.988369, loss: 0.513881
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.0001
# train: jaccard: 0.005862, bce: 0.037265, dice: 0.988046, loss: 0.512655
# val: jaccard: 0.005574, bce: 0.031484, dice: 0.988297, loss: 0.509890
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.0001
# train: jaccard: 0.006711, bce: 0.032756, dice: 0.986321, loss: 0.509539
# val: jaccard: 0.008962, bce: 0.029330, dice: 0.982318, loss: 0.505824
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.0001
# train: jaccard: 0.011843, bce: 0.031011, dice: 0.976447, loss: 0.503729
# val: jaccard: 0.016263, bce: 0.028999, dice: 0.967812, loss: 0.498405
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.0001
# train: jaccard: 0.020290, bce: 0.030533, dice: 0.959152, loss: 0.494843
# val: jaccard: 0.025661, bce: 0.027449, dice: 0.948930, loss: 0.488190
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.0001
# train: jaccard: 0.032194, bce: 0.027068, dice: 0.936167, loss: 0.481618
# val: jaccard: 0.041277, bce: 0.022071, dice: 0.919394, loss: 0.470732
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.0001
# train: jaccard: 0.049322, bce: 0.022298, dice: 0.904385, loss: 0.463342
# val: jaccard: 0.059708, bce: 0.019136, dice: 0.885913, loss: 0.452525
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.0001
# train: jaccard: 0.065420, bce: 0.020283, dice: 0.875268, loss: 0.447776
# val: jaccard: 0.074506, bce: 0.018136, dice: 0.856745, loss: 0.437441
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.0001
# train: jaccard: 0.080435, bce: 0.019955, dice: 0.845321, loss: 0.432638
# val: jaccard: 0.086389, bce: 0.019152, dice: 0.829933, loss: 0.424543
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.0001
# train: jaccard: 0.094377, bce: 0.020241, dice: 0.820611, loss: 0.420426
# val: jaccard: 0.104400, bce: 0.017431, dice: 0.805989, loss: 0.411710
# saving best model
# 0m 2s
# Best val loss: 0.411710
# test: jaccard: 0.108286, bce: 0.022062, dice: 0.807537, loss: 0.414800
# (3, 6, 192, 192)

# %%
utilities.run(UNet,gma=0.5)
# Out:
# Epoch 0/19
# ----------
# LR 0.0001
# train: jaccard: 0.005007, bce: 0.686090, dice: 0.990105, loss: 0.838097
# val: jaccard: 0.004563, bce: 0.680946, dice: 0.990959, loss: 0.835953
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.0001
# train: jaccard: 0.005019, bce: 0.678081, dice: 0.990085, loss: 0.834083
# val: jaccard: 0.004574, bce: 0.673028, dice: 0.990944, loss: 0.831986
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.0001
# train: jaccard: 0.005034, bce: 0.669356, dice: 0.990063, loss: 0.829710
# val: jaccard: 0.004590, bce: 0.662016, dice: 0.990927, loss: 0.826471
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.0001
# train: jaccard: 0.005059, bce: 0.655954, dice: 0.990036, loss: 0.822995
# val: jaccard: 0.004617, bce: 0.644080, dice: 0.990899, loss: 0.817489
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.0001
# train: jaccard: 0.005097, bce: 0.633752, dice: 0.989998, loss: 0.811875
# val: jaccard: 0.004654, bce: 0.612712, dice: 0.990866, loss: 0.801789
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.0001
# train: jaccard: 0.005131, bce: 0.593060, dice: 0.989985, loss: 0.791522
# val: jaccard: 0.004656, bce: 0.549035, dice: 0.990938, loss: 0.769986
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.0001
# train: jaccard: 0.005090, bce: 0.494096, dice: 0.990217, loss: 0.742157
# val: jaccard: 0.004463, bce: 0.354564, dice: 0.991790, loss: 0.673177
# saving best model
# 0m 2s
# Epoch 7/19
# ----------
# LR 0.0001
# train: jaccard: 0.003961, bce: 0.219718, dice: 0.993158, loss: 0.606438
# val: jaccard: 0.000901, bce: 0.063859, dice: 0.995878, loss: 0.529868
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.0001
# train: jaccard: 0.000199, bce: 0.109855, dice: 0.994742, loss: 0.552299
# val: jaccard: 0.000000, bce: 0.110003, dice: 0.993613, loss: 0.551808
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.0001
# train: jaccard: 0.000027, bce: 0.086849, dice: 0.994614, loss: 0.540731
# val: jaccard: 0.000604, bce: 0.043730, dice: 0.995480, loss: 0.519605
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.0001
# train: jaccard: 0.002969, bce: 0.043824, dice: 0.993039, loss: 0.518432
# val: jaccard: 0.005906, bce: 0.047092, dice: 0.988842, loss: 0.517967
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.0001
# train: jaccard: 0.007869, bce: 0.048362, dice: 0.985346, loss: 0.516854
# val: jaccard: 0.008705, bce: 0.040235, dice: 0.982857, loss: 0.511546
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.0001
# train: jaccard: 0.010477, bce: 0.036013, dice: 0.980122, loss: 0.508067
# val: jaccard: 0.011161, bce: 0.028021, dice: 0.978356, loss: 0.503189
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.0001
# train: jaccard: 0.014388, bce: 0.028325, dice: 0.972506, loss: 0.500416
# val: jaccard: 0.019461, bce: 0.024913, dice: 0.963136, loss: 0.494025
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.0001
# train: jaccard: 0.025947, bce: 0.026200, dice: 0.950816, loss: 0.488508
# val: jaccard: 0.033964, bce: 0.023783, dice: 0.935816, loss: 0.479800
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.0001
# train: jaccard: 0.042147, bce: 0.024215, dice: 0.919978, loss: 0.472097
# val: jaccard: 0.052892, bce: 0.020415, dice: 0.900194, loss: 0.460304
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.0001
# train: jaccard: 0.062078, bce: 0.020821, dice: 0.883194, loss: 0.452007
# val: jaccard: 0.072960, bce: 0.017925, dice: 0.863080, loss: 0.440503
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.0001
# train: jaccard: 0.080592, bce: 0.019043, dice: 0.849814, loss: 0.434429
# val: jaccard: 0.089729, bce: 0.017207, dice: 0.830798, loss: 0.424003
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.0001
# train: jaccard: 0.097241, bce: 0.018836, dice: 0.820471, loss: 0.419653
# val: jaccard: 0.104321, bce: 0.017572, dice: 0.807240, loss: 0.412406
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.0001
# train: jaccard: 0.112742, bce: 0.018649, dice: 0.800775, loss: 0.409712
# val: jaccard: 0.120185, bce: 0.016367, dice: 0.790965, loss: 0.403666
# saving best model
# 0m 2s
# Best val loss: 0.403666
# test: jaccard: 0.124526, bce: 0.020741, dice: 0.791363, loss: 0.406052
# (3, 6, 192, 192)

# %%
utilities.run(UNet,gma=0.9)
# Out:
# Epoch 0/19
# ----------
# LR 0.0001
# train: jaccard: 0.005042, bce: 0.680836, dice: 0.990002, loss: 0.835419
# val: jaccard: 0.004598, bce: 0.670885, dice: 0.990856, loss: 0.830870
# saving best model
# 0m 2s
# Epoch 1/19
# ----------
# LR 0.0001
# train: jaccard: 0.005064, bce: 0.663364, dice: 0.989963, loss: 0.826663
# val: jaccard: 0.004626, bce: 0.648534, dice: 0.990806, loss: 0.819670
# saving best model
# 0m 2s
# Epoch 2/19
# ----------
# LR 0.0001
# train: jaccard: 0.005102, bce: 0.636666, dice: 0.989897, loss: 0.813281
# val: jaccard: 0.004666, bce: 0.613024, dice: 0.990732, loss: 0.801878
# saving best model
# 0m 2s
# Epoch 3/19
# ----------
# LR 0.0001
# train: jaccard: 0.005157, bce: 0.592421, dice: 0.989809, loss: 0.791115
# val: jaccard: 0.004728, bce: 0.549278, dice: 0.990628, loss: 0.769953
# saving best model
# 0m 2s
# Epoch 4/19
# ----------
# LR 0.0001
# train: jaccard: 0.005224, bce: 0.507061, dice: 0.989725, loss: 0.748393
# val: jaccard: 0.004754, bce: 0.408544, dice: 0.990618, loss: 0.699581
# saving best model
# 0m 2s
# Epoch 5/19
# ----------
# LR 0.0001
# train: jaccard: 0.005033, bce: 0.293283, dice: 0.990236, loss: 0.641759
# val: jaccard: 0.003216, bce: 0.075231, dice: 0.993794, loss: 0.534512
# saving best model
# 0m 2s
# Epoch 6/19
# ----------
# LR 0.0001
# train: jaccard: 0.001203, bce: 0.067658, dice: 0.995322, loss: 0.531490
# val: jaccard: 0.000000, bce: 0.098977, dice: 0.993734, loss: 0.546356
# 0m 3s
# Epoch 7/19
# ----------
# LR 0.0001
# train: jaccard: 0.000000, bce: 0.102875, dice: 0.993947, loss: 0.548411
# val: jaccard: 0.000004, bce: 0.062745, dice: 0.994429, loss: 0.528587
# saving best model
# 0m 2s
# Epoch 8/19
# ----------
# LR 0.0001
# train: jaccard: 0.000460, bce: 0.050403, dice: 0.994848, loss: 0.522626
# val: jaccard: 0.003556, bce: 0.030049, dice: 0.990717, loss: 0.510383
# saving best model
# 0m 2s
# Epoch 9/19
# ----------
# LR 0.0001
# train: jaccard: 0.008503, bce: 0.033007, dice: 0.981061, loss: 0.507034
# val: jaccard: 0.013984, bce: 0.037254, dice: 0.968930, loss: 0.503092
# saving best model
# 0m 2s
# Epoch 10/19
# ----------
# LR 0.0001
# train: jaccard: 0.018072, bce: 0.038922, dice: 0.961215, loss: 0.500068
# val: jaccard: 0.021939, bce: 0.033508, dice: 0.952831, loss: 0.493170
# saving best model
# 0m 2s
# Epoch 11/19
# ----------
# LR 0.0001
# train: jaccard: 0.028311, bce: 0.030193, dice: 0.941546, loss: 0.485869
# val: jaccard: 0.035916, bce: 0.022623, dice: 0.927965, loss: 0.475294
# saving best model
# 0m 2s
# Epoch 12/19
# ----------
# LR 0.0001
# train: jaccard: 0.044744, bce: 0.022508, dice: 0.914203, loss: 0.468355
# val: jaccard: 0.056708, bce: 0.019268, dice: 0.895164, loss: 0.457216
# saving best model
# 0m 2s
# Epoch 13/19
# ----------
# LR 0.0001
# train: jaccard: 0.066983, bce: 0.020374, dice: 0.879319, loss: 0.449846
# val: jaccard: 0.080523, bce: 0.018231, dice: 0.856958, loss: 0.437594
# saving best model
# 0m 2s
# Epoch 14/19
# ----------
# LR 0.0001
# train: jaccard: 0.089624, bce: 0.019676, dice: 0.843551, loss: 0.431614
# val: jaccard: 0.100529, bce: 0.017968, dice: 0.824774, loss: 0.421371
# saving best model
# 0m 2s
# Epoch 15/19
# ----------
# LR 0.0001
# train: jaccard: 0.108410, bce: 0.019574, dice: 0.814818, loss: 0.417196
# val: jaccard: 0.117954, bce: 0.017915, dice: 0.799519, loss: 0.408717
# saving best model
# 0m 2s
# Epoch 16/19
# ----------
# LR 0.0001
# train: jaccard: 0.125409, bce: 0.019525, dice: 0.791962, loss: 0.405743
# val: jaccard: 0.134371, bce: 0.017869, dice: 0.780049, loss: 0.398959
# saving best model
# 0m 2s
# Epoch 17/19
# ----------
# LR 0.0001
# train: jaccard: 0.140699, bce: 0.019568, dice: 0.774418, loss: 0.396993
# val: jaccard: 0.148495, bce: 0.018075, dice: 0.764967, loss: 0.391521
# saving best model
# 0m 2s
# Epoch 18/19
# ----------
# LR 0.0001
# train: jaccard: 0.154061, bce: 0.019908, dice: 0.760110, loss: 0.390009
# val: jaccard: 0.160570, bce: 0.018644, dice: 0.752197, loss: 0.385420
# saving best model
# 0m 2s
# Epoch 19/19
# ----------
# LR 0.0001
# train: jaccard: 0.165932, bce: 0.020660, dice: 0.747471, loss: 0.384065
# val: jaccard: 0.172227, bce: 0.019568, dice: 0.740249, loss: 0.379909
# saving best model
# 0m 2s
# Best val loss: 0.379909
# test: jaccard: 0.180096, bce: 0.024953, dice: 0.742257, loss: 0.383605
# (3, 6, 192, 192)

# %%
utilities.run(UNet,epochs=60)
# Out:
# Epoch 0/59
# ----------
# LR 0.0001
# train: jaccard: 0.004990, bce: 0.701579, dice: 0.990091, loss: 0.845835
# val: jaccard: 0.004546, bce: 0.692653, dice: 0.990937, loss: 0.841795
# saving best model
# 0m 3s
# Epoch 1/59
# ----------
# LR 0.0001
# train: jaccard: 0.005001, bce: 0.686213, dice: 0.990056, loss: 0.838135
# val: jaccard: 0.004549, bce: 0.673945, dice: 0.990918, loss: 0.832432
# saving best model
# 0m 2s
# Epoch 2/59
# ----------
# LR 0.0001
# train: jaccard: 0.004999, bce: 0.663670, dice: 0.990043, loss: 0.826857
# val: jaccard: 0.004535, bce: 0.642876, dice: 0.990922, loss: 0.816899
# saving best model
# 0m 2s
# Epoch 3/59
# ----------
# LR 0.0001
# train: jaccard: 0.004965, bce: 0.623846, dice: 0.990080, loss: 0.806963
# val: jaccard: 0.004451, bce: 0.582248, dice: 0.991040, loss: 0.786644
# saving best model
# 0m 2s
# Epoch 4/59
# ----------
# LR 0.0001
# train: jaccard: 0.004763, bce: 0.533877, dice: 0.990406, loss: 0.762141
# val: jaccard: 0.003925, bce: 0.407050, dice: 0.991959, loss: 0.699505
# saving best model
# 0m 2s
# Epoch 5/59
# ----------
# LR 0.0001
# train: jaccard: 0.003141, bce: 0.255407, dice: 0.993506, loss: 0.624456
# val: jaccard: 0.000393, bce: 0.056431, dice: 0.997809, loss: 0.527120
# saving best model
# 0m 2s
# Epoch 6/59
# ----------
# LR 0.0001
# train: jaccard: 0.000104, bce: 0.100823, dice: 0.996156, loss: 0.548489
# val: jaccard: 0.000000, bce: 0.132715, dice: 0.994144, loss: 0.563430
# 0m 2s
# Epoch 7/59
# ----------
# LR 0.0001
# train: jaccard: 0.000000, bce: 0.115315, dice: 0.994825, loss: 0.555070
# val: jaccard: 0.000022, bce: 0.057322, dice: 0.996023, loss: 0.526673
# saving best model
# 0m 2s
# Epoch 8/59
# ----------
# LR 0.0001
# train: jaccard: 0.000829, bce: 0.048470, dice: 0.995778, loss: 0.522124
# val: jaccard: 0.003413, bce: 0.040933, dice: 0.992520, loss: 0.516726
# saving best model
# 0m 2s
# Epoch 9/59
# ----------
# LR 0.0001
# train: jaccard: 0.005461, bce: 0.048331, dice: 0.988583, loss: 0.518457
# val: jaccard: 0.006712, bce: 0.050447, dice: 0.985417, loss: 0.517932
# 0m 2s
# Epoch 10/59
# ----------
# LR 0.0001
# train: jaccard: 0.008038, bce: 0.046097, dice: 0.983149, loss: 0.514623
# val: jaccard: 0.007843, bce: 0.034494, dice: 0.983388, loss: 0.508941
# saving best model
# 0m 2s
# Epoch 11/59
# ----------
# LR 0.0001
# train: jaccard: 0.008766, bce: 0.032908, dice: 0.982177, loss: 0.507542
# val: jaccard: 0.008812, bce: 0.028101, dice: 0.981927, loss: 0.505014
# saving best model
# 0m 2s
# Epoch 12/59
# ----------
# LR 0.0001
# train: jaccard: 0.011638, bce: 0.029060, dice: 0.977229, loss: 0.503144
# val: jaccard: 0.014965, bce: 0.026332, dice: 0.970218, loss: 0.498275
# saving best model
# 0m 2s
# Epoch 13/59
# ----------
# LR 0.0001
# train: jaccard: 0.020046, bce: 0.027801, dice: 0.961138, loss: 0.494470
# val: jaccard: 0.025087, bce: 0.025979, dice: 0.949647, loss: 0.487813
# saving best model
# 0m 2s
# Epoch 14/59
# ----------
# LR 0.0001
# train: jaccard: 0.031808, bce: 0.026700, dice: 0.937957, loss: 0.482328
# val: jaccard: 0.039591, bce: 0.023026, dice: 0.921546, loss: 0.472286
# saving best model
# 0m 2s
# Epoch 15/59
# ----------
# LR 0.0001
# train: jaccard: 0.049095, bce: 0.022984, dice: 0.905412, loss: 0.464198
# val: jaccard: 0.061270, bce: 0.019353, dice: 0.883174, loss: 0.451264
# saving best model
# 0m 2s
# Epoch 16/59
# ----------
# LR 0.0001
# train: jaccard: 0.070436, bce: 0.020283, dice: 0.868766, loss: 0.444524
# val: jaccard: 0.081982, bce: 0.017955, dice: 0.848047, loss: 0.433001
# saving best model
# 0m 2s
# Epoch 17/59
# ----------
# LR 0.0001
# train: jaccard: 0.090604, bce: 0.019402, dice: 0.834693, loss: 0.427048
# val: jaccard: 0.099793, bce: 0.017978, dice: 0.817375, loss: 0.417676
# saving best model
# 0m 2s
# Epoch 18/59
# ----------
# LR 0.0001
# train: jaccard: 0.106788, bce: 0.019616, dice: 0.809344, loss: 0.414480
# val: jaccard: 0.114972, bce: 0.017654, dice: 0.796582, loss: 0.407118
# saving best model
# 0m 2s
# Epoch 19/59
# ----------
# LR 0.0001
# train: jaccard: 0.120864, bce: 0.018905, dice: 0.791777, loss: 0.405341
# val: jaccard: 0.125892, bce: 0.016965, dice: 0.783892, loss: 0.400428
# saving best model
# 0m 2s
# Epoch 20/59
# ----------
# LR 0.0001
# train: jaccard: 0.129723, bce: 0.018643, dice: 0.781206, loss: 0.399925
# val: jaccard: 0.132801, bce: 0.017291, dice: 0.774248, loss: 0.395770
# saving best model
# 0m 2s
# Epoch 21/59
# ----------
# LR 0.0001
# train: jaccard: 0.136117, bce: 0.019081, dice: 0.772115, loss: 0.395598
# val: jaccard: 0.139116, bce: 0.017571, dice: 0.765537, loss: 0.391554
# saving best model
# 0m 2s
# Epoch 22/59
# ----------
# LR 0.0001
# train: jaccard: 0.145037, bce: 0.018853, dice: 0.761246, loss: 0.390049
# val: jaccard: 0.150019, bce: 0.016338, dice: 0.756418, loss: 0.386378
# saving best model
# 0m 2s
# Epoch 23/59
# ----------
# LR 0.0001
# train: jaccard: 0.156106, bce: 0.018377, dice: 0.750014, loss: 0.384196
# val: jaccard: 0.158281, bce: 0.017710, dice: 0.742816, loss: 0.380263
# saving best model
# 0m 2s
# Epoch 24/59
# ----------
# LR 0.0001
# train: jaccard: 0.166851, bce: 0.019130, dice: 0.737764, loss: 0.378447
# val: jaccard: 0.173175, bce: 0.017412, dice: 0.732084, loss: 0.374748
# saving best model
# 0m 3s
# Epoch 25/59
# ----------
# LR 0.0001
# train: jaccard: 0.182281, bce: 0.019127, dice: 0.725290, loss: 0.372209
# val: jaccard: 0.184739, bce: 0.018381, dice: 0.717278, loss: 0.367829
# saving best model
# 0m 3s
# Epoch 26/59
# ----------
# LR 0.0001
# train: jaccard: 0.194364, bce: 0.020084, dice: 0.710035, loss: 0.365060
# val: jaccard: 0.198993, bce: 0.018648, dice: 0.701297, loss: 0.359972
# saving best model
# 0m 2s
# Epoch 27/59
# ----------
# LR 0.0001
# train: jaccard: 0.210902, bce: 0.020152, dice: 0.692290, loss: 0.356221
# val: jaccard: 0.212627, bce: 0.018511, dice: 0.684789, loss: 0.351650
# saving best model
# 0m 2s
# Epoch 28/59
# ----------
# LR 0.0001
# train: jaccard: 0.226684, bce: 0.020292, dice: 0.671468, loss: 0.345880
# val: jaccard: 0.226834, bce: 0.018760, dice: 0.660327, loss: 0.339543
# saving best model
# 0m 2s
# Epoch 29/59
# ----------
# LR 1e-05
# train: jaccard: 0.236623, bce: 0.020085, dice: 0.654762, loss: 0.337424
# val: jaccard: 0.229394, bce: 0.018977, dice: 0.656548, loss: 0.337762
# saving best model
# 0m 2s
# Epoch 30/59
# ----------
# LR 1e-05
# train: jaccard: 0.238652, bce: 0.020435, dice: 0.651356, loss: 0.335896
# val: jaccard: 0.231821, bce: 0.019124, dice: 0.653390, loss: 0.336257
# saving best model
# 0m 2s
# Epoch 31/59
# ----------
# LR 1e-05
# train: jaccard: 0.241236, bce: 0.020377, dice: 0.648192, loss: 0.334284
# val: jaccard: 0.233808, bce: 0.018863, dice: 0.650674, loss: 0.334769
# saving best model
# 0m 2s
# Epoch 32/59
# ----------
# LR 1e-05
# train: jaccard: 0.243990, bce: 0.020072, dice: 0.645242, loss: 0.332657
# val: jaccard: 0.235936, bce: 0.018774, dice: 0.647830, loss: 0.333302
# saving best model
# 0m 2s
# Epoch 33/59
# ----------
# LR 1e-05
# train: jaccard: 0.246430, bce: 0.020103, dice: 0.641890, loss: 0.330997
# val: jaccard: 0.238500, bce: 0.018914, dice: 0.644169, loss: 0.331542
# saving best model
# 0m 2s
# Epoch 34/59
# ----------
# LR 1e-05
# train: jaccard: 0.248801, bce: 0.020208, dice: 0.638485, loss: 0.329346
# val: jaccard: 0.240760, bce: 0.018887, dice: 0.640894, loss: 0.329891
# saving best model
# 0m 2s
# Epoch 35/59
# ----------
# LR 1e-05
# train: jaccard: 0.251245, bce: 0.020102, dice: 0.635218, loss: 0.327660
# val: jaccard: 0.242848, bce: 0.018830, dice: 0.637816, loss: 0.328323
# saving best model
# 0m 2s
# Epoch 36/59
# ----------
# LR 1e-05
# train: jaccard: 0.253649, bce: 0.020061, dice: 0.631927, loss: 0.325994
# val: jaccard: 0.245155, bce: 0.018886, dice: 0.634374, loss: 0.326630
# saving best model
# 0m 2s
# Epoch 37/59
# ----------
# LR 1e-05
# train: jaccard: 0.255804, bce: 0.020174, dice: 0.628528, loss: 0.324351
# val: jaccard: 0.247299, bce: 0.018912, dice: 0.631014, loss: 0.324963
# saving best model
# 0m 3s
# Epoch 38/59
# ----------
# LR 1e-05
# train: jaccard: 0.258318, bce: 0.020035, dice: 0.625319, loss: 0.322677
# val: jaccard: 0.249121, bce: 0.018792, dice: 0.628191, loss: 0.323492
# saving best model
# 0m 2s
# Epoch 39/59
# ----------
# LR 1e-05
# train: jaccard: 0.260792, bce: 0.019990, dice: 0.622001, loss: 0.320996
# val: jaccard: 0.251748, bce: 0.018906, dice: 0.624403, loss: 0.321654
# saving best model
# 0m 2s
# Epoch 40/59
# ----------
# LR 1e-05
# train: jaccard: 0.263037, bce: 0.020117, dice: 0.618561, loss: 0.319339
# val: jaccard: 0.253755, bce: 0.018866, dice: 0.621133, loss: 0.320000
# saving best model
# 0m 2s
# Epoch 41/59
# ----------
# LR 1e-05
# train: jaccard: 0.265639, bce: 0.019925, dice: 0.615274, loss: 0.317600
# val: jaccard: 0.255757, bce: 0.018751, dice: 0.618140, loss: 0.318446
# saving best model
# 0m 2s
# Epoch 42/59
# ----------
# LR 1e-05
# train: jaccard: 0.268120, bce: 0.019889, dice: 0.611829, loss: 0.315859
# val: jaccard: 0.258337, bce: 0.018877, dice: 0.614111, loss: 0.316494
# saving best model
# 0m 2s
# Epoch 43/59
# ----------
# LR 1e-05
# train: jaccard: 0.270434, bce: 0.019958, dice: 0.608299, loss: 0.314129
# val: jaccard: 0.260628, bce: 0.018767, dice: 0.610751, loss: 0.314759
# saving best model
# 0m 2s
# Epoch 44/59
# ----------
# LR 1e-05
# train: jaccard: 0.273038, bce: 0.019840, dice: 0.604741, loss: 0.312291
# val: jaccard: 0.263048, bce: 0.018712, dice: 0.607166, loss: 0.312939
# saving best model
# 0m 2s
# Epoch 45/59
# ----------
# LR 1e-05
# train: jaccard: 0.275922, bce: 0.019695, dice: 0.601148, loss: 0.310421
# val: jaccard: 0.265950, bce: 0.018638, dice: 0.603486, loss: 0.311062
# saving best model
# 0m 2s
# Epoch 46/59
# ----------
# LR 1e-05
# train: jaccard: 0.278945, bce: 0.019680, dice: 0.597327, loss: 0.308504
# val: jaccard: 0.268703, bce: 0.018618, dice: 0.599451, loss: 0.309034
# saving best model
# 0m 2s
# Epoch 47/59
# ----------
# LR 1e-05
# train: jaccard: 0.281977, bce: 0.019486, dice: 0.593662, loss: 0.306574
# val: jaccard: 0.271761, bce: 0.018502, dice: 0.595630, loss: 0.307066
# saving best model
# 0m 2s
# Epoch 48/59
# ----------
# LR 1e-05
# train: jaccard: 0.285466, bce: 0.019537, dice: 0.589511, loss: 0.304524
# val: jaccard: 0.275220, bce: 0.018531, dice: 0.591303, loss: 0.304917
# saving best model
# 0m 2s
# Epoch 49/59
# ----------
# LR 1e-05
# train: jaccard: 0.288703, bce: 0.019317, dice: 0.585666, loss: 0.302491
# val: jaccard: 0.277886, bce: 0.018309, dice: 0.587714, loss: 0.303012
# saving best model
# 0m 2s
# Epoch 50/59
# ----------
# LR 1e-05
# train: jaccard: 0.292036, bce: 0.019362, dice: 0.581658, loss: 0.300510
# val: jaccard: 0.281966, bce: 0.018413, dice: 0.583033, loss: 0.300723
# saving best model
# 0m 3s
# Epoch 51/59
# ----------
# LR 1e-05
# train: jaccard: 0.294824, bce: 0.019097, dice: 0.578029, loss: 0.298563
# val: jaccard: 0.284806, bce: 0.018204, dice: 0.579429, loss: 0.298817
# saving best model
# 0m 2s
# Epoch 52/59
# ----------
# LR 1e-05
# train: jaccard: 0.299572, bce: 0.019164, dice: 0.573407, loss: 0.296285
# val: jaccard: 0.289110, bce: 0.018343, dice: 0.575324, loss: 0.296833
# saving best model
# 0m 3s
# Epoch 53/59
# ----------
# LR 1e-05
# train: jaccard: 0.302757, bce: 0.019082, dice: 0.569686, loss: 0.294384
# val: jaccard: 0.291489, bce: 0.018078, dice: 0.571745, loss: 0.294911
# saving best model
# 0m 2s
# Epoch 54/59
# ----------
# LR 1e-05
# train: jaccard: 0.306466, bce: 0.018927, dice: 0.566002, loss: 0.292465
# val: jaccard: 0.296107, bce: 0.018136, dice: 0.567777, loss: 0.292956
# saving best model
# 0m 3s
# Epoch 55/59
# ----------
# LR 1e-05
# train: jaccard: 0.310424, bce: 0.018903, dice: 0.562246, loss: 0.290575
# val: jaccard: 0.298576, bce: 0.017973, dice: 0.564398, loss: 0.291185
# saving best model
# 0m 2s
# Epoch 56/59
# ----------
# LR 1e-05
# train: jaccard: 0.313083, bce: 0.018754, dice: 0.558860, loss: 0.288807
# val: jaccard: 0.302563, bce: 0.018068, dice: 0.560713, loss: 0.289391
# saving best model
# 0m 2s
# Epoch 57/59
# ----------
# LR 1e-05
# train: jaccard: 0.316823, bce: 0.018837, dice: 0.555324, loss: 0.287081
# val: jaccard: 0.305597, bce: 0.017919, dice: 0.557309, loss: 0.287614
# saving best model
# 0m 2s
# Epoch 58/59
# ----------
# LR 1e-05
# train: jaccard: 0.319875, bce: 0.018594, dice: 0.552088, loss: 0.285341
# val: jaccard: 0.309003, bce: 0.017841, dice: 0.554179, loss: 0.286010
# saving best model
# 0m 2s
# Epoch 59/59
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.322516, bce: 0.018596, dice: 0.549775, loss: 0.284185
# val: jaccard: 0.309316, bce: 0.017848, dice: 0.553877, loss: 0.285862
# saving best model
# 0m 2s
# Best val loss: 0.285862
# test: jaccard: 0.315326, bce: 0.022669, dice: 0.549848, loss: 0.286258
# (3, 6, 192, 192)

# %%
utilities.run(UNet,epochs=100)
# Out:
# Epoch 0/99
# ----------
# LR 0.0001
# train: jaccard: 0.004976, bce: 0.708659, dice: 0.990093, loss: 0.849376
# val: jaccard: 0.004578, bce: 0.692172, dice: 0.990869, loss: 0.841520
# saving best model
# 0m 3s
# Epoch 1/99
# ----------
# LR 0.0001
# train: jaccard: 0.005052, bce: 0.679153, dice: 0.989926, loss: 0.834539
# val: jaccard: 0.004648, bce: 0.654093, dice: 0.990706, loss: 0.822399
# saving best model
# 0m 2s
# Epoch 2/99
# ----------
# LR 0.0001
# train: jaccard: 0.005125, bce: 0.635114, dice: 0.989741, loss: 0.812428
# val: jaccard: 0.004708, bce: 0.598453, dice: 0.990543, loss: 0.794498
# saving best model
# 0m 2s
# Epoch 3/99
# ----------
# LR 0.0001
# train: jaccard: 0.005182, bce: 0.568846, dice: 0.989553, loss: 0.779200
# val: jaccard: 0.004742, bce: 0.508208, dice: 0.990383, loss: 0.749296
# saving best model
# 0m 2s
# Epoch 4/99
# ----------
# LR 0.0001
# train: jaccard: 0.005136, bce: 0.449584, dice: 0.989480, loss: 0.719532
# val: jaccard: 0.004417, bce: 0.310853, dice: 0.990761, loss: 0.650807
# saving best model
# 0m 2s
# Epoch 5/99
# ----------
# LR 0.0001
# train: jaccard: 0.003656, bce: 0.183334, dice: 0.992206, loss: 0.587770
# val: jaccard: 0.000393, bce: 0.050616, dice: 0.997090, loss: 0.523853
# saving best model
# 0m 2s
# Epoch 6/99
# ----------
# LR 0.0001
# train: jaccard: 0.000097, bce: 0.090457, dice: 0.995814, loss: 0.543136
# val: jaccard: 0.000000, bce: 0.104380, dice: 0.994325, loss: 0.549353
# 0m 2s
# Epoch 7/99
# ----------
# LR 0.0001
# train: jaccard: 0.000012, bce: 0.089114, dice: 0.995141, loss: 0.542127
# val: jaccard: 0.000296, bce: 0.044055, dice: 0.995853, loss: 0.519954
# saving best model
# 0m 2s
# Epoch 8/99
# ----------
# LR 0.0001
# train: jaccard: 0.003180, bce: 0.039046, dice: 0.992054, loss: 0.515550
# val: jaccard: 0.009950, bce: 0.034024, dice: 0.980963, loss: 0.507493
# saving best model
# 0m 2s
# Epoch 9/99
# ----------
# LR 0.0001
# train: jaccard: 0.013632, bce: 0.040620, dice: 0.973416, loss: 0.507018
# val: jaccard: 0.016719, bce: 0.042449, dice: 0.967498, loss: 0.504974
# saving best model
# 0m 2s
# Epoch 10/99
# ----------
# LR 0.0001
# train: jaccard: 0.020662, bce: 0.039354, dice: 0.959701, loss: 0.499528
# val: jaccard: 0.024562, bce: 0.029063, dice: 0.953379, loss: 0.491221
# saving best model
# 0m 2s
# Epoch 11/99
# ----------
# LR 0.0001
# train: jaccard: 0.029285, bce: 0.026977, dice: 0.944227, loss: 0.485602
# val: jaccard: 0.035802, bce: 0.021760, dice: 0.933634, loss: 0.477697
# saving best model
# 0m 2s
# Epoch 12/99
# ----------
# LR 0.0001
# train: jaccard: 0.044336, bce: 0.022418, dice: 0.916857, loss: 0.469637
# val: jaccard: 0.056711, bce: 0.019985, dice: 0.894735, loss: 0.457360
# saving best model
# 0m 2s
# Epoch 13/99
# ----------
# LR 0.0001
# train: jaccard: 0.067141, bce: 0.021145, dice: 0.875096, loss: 0.448121
# val: jaccard: 0.079900, bce: 0.018947, dice: 0.852459, loss: 0.435703
# saving best model
# 0m 2s
# Epoch 14/99
# ----------
# LR 0.0001
# train: jaccard: 0.089455, bce: 0.019970, dice: 0.837308, loss: 0.428639
# val: jaccard: 0.100775, bce: 0.017625, dice: 0.819627, loss: 0.418626
# saving best model
# 0m 2s
# Epoch 15/99
# ----------
# LR 0.0001
# train: jaccard: 0.107838, bce: 0.018997, dice: 0.810748, loss: 0.414872
# val: jaccard: 0.116133, bce: 0.017115, dice: 0.798063, loss: 0.407589
# saving best model
# 0m 2s
# Epoch 16/99
# ----------
# LR 0.0001
# train: jaccard: 0.119938, bce: 0.018768, dice: 0.793538, loss: 0.406153
# val: jaccard: 0.125711, bce: 0.017095, dice: 0.783908, loss: 0.400501
# saving best model
# 0m 2s
# Epoch 17/99
# ----------
# LR 0.0001
# train: jaccard: 0.128543, bce: 0.018667, dice: 0.781276, loss: 0.399971
# val: jaccard: 0.133396, bce: 0.016971, dice: 0.773505, loss: 0.395238
# saving best model
# 0m 2s
# Epoch 18/99
# ----------
# LR 0.0001
# train: jaccard: 0.136329, bce: 0.018464, dice: 0.771332, loss: 0.394898
# val: jaccard: 0.141008, bce: 0.016782, dice: 0.764101, loss: 0.390441
# saving best model
# 0m 2s
# Epoch 19/99
# ----------
# LR 0.0001
# train: jaccard: 0.144119, bce: 0.018268, dice: 0.761986, loss: 0.390127
# val: jaccard: 0.148652, bce: 0.016673, dice: 0.754623, loss: 0.385648
# saving best model
# 0m 2s
# Epoch 20/99
# ----------
# LR 0.0001
# train: jaccard: 0.152801, bce: 0.018146, dice: 0.752027, loss: 0.385087
# val: jaccard: 0.159243, bce: 0.016539, dice: 0.743677, loss: 0.380108
# saving best model
# 0m 2s
# Epoch 21/99
# ----------
# LR 0.0001
# train: jaccard: 0.166062, bce: 0.017904, dice: 0.740564, loss: 0.379234
# val: jaccard: 0.171389, bce: 0.016603, dice: 0.732083, loss: 0.374343
# saving best model
# 0m 2s
# Epoch 22/99
# ----------
# LR 0.0001
# train: jaccard: 0.179873, bce: 0.018064, dice: 0.726954, loss: 0.372509
# val: jaccard: 0.191782, bce: 0.016498, dice: 0.716237, loss: 0.366367
# saving best model
# 0m 2s
# Epoch 23/99
# ----------
# LR 0.0001
# train: jaccard: 0.200436, bce: 0.017941, dice: 0.707442, loss: 0.362691
# val: jaccard: 0.207108, bce: 0.016555, dice: 0.690681, loss: 0.353618
# saving best model
# 0m 2s
# Epoch 24/99
# ----------
# LR 0.0001
# train: jaccard: 0.217910, bce: 0.018245, dice: 0.678756, loss: 0.348501
# val: jaccard: 0.229023, bce: 0.017770, dice: 0.657995, loss: 0.337883
# saving best model
# 0m 2s
# Epoch 25/99
# ----------
# LR 0.0001
# train: jaccard: 0.239737, bce: 0.019411, dice: 0.642669, loss: 0.331040
# val: jaccard: 0.246953, bce: 0.019363, dice: 0.621245, loss: 0.320304
# saving best model
# 0m 2s
# Epoch 26/99
# ----------
# LR 0.0001
# train: jaccard: 0.265402, bce: 0.020530, dice: 0.600727, loss: 0.310628
# val: jaccard: 0.275383, bce: 0.019046, dice: 0.581192, loss: 0.300119
# saving best model
# 0m 2s
# Epoch 27/99
# ----------
# LR 0.0001
# train: jaccard: 0.295139, bce: 0.021000, dice: 0.570708, loss: 0.295854
# val: jaccard: 0.295705, bce: 0.019825, dice: 0.555771, loss: 0.287798
# saving best model
# 0m 2s
# Epoch 28/99
# ----------
# LR 0.0001
# train: jaccard: 0.323375, bce: 0.021061, dice: 0.538828, loss: 0.279944
# val: jaccard: 0.305142, bce: 0.020544, dice: 0.548091, loss: 0.284317
# saving best model
# 0m 3s
# Epoch 29/99
# ----------
# LR 1e-05
# train: jaccard: 0.320995, bce: 0.021690, dice: 0.535746, loss: 0.278718
# val: jaccard: 0.342867, bce: 0.019140, dice: 0.504484, loss: 0.261812
# saving best model
# 0m 2s
# Epoch 30/99
# ----------
# LR 1e-05
# train: jaccard: 0.345765, bce: 0.020974, dice: 0.514369, loss: 0.267672
# val: jaccard: 0.331273, bce: 0.020184, dice: 0.523310, loss: 0.271747
# 0m 2s
# Epoch 31/99
# ----------
# LR 1e-05
# train: jaccard: 0.346461, bce: 0.021231, dice: 0.515090, loss: 0.268161
# val: jaccard: 0.345805, bce: 0.019412, dice: 0.501137, loss: 0.260275
# saving best model
# 0m 2s
# Epoch 32/99
# ----------
# LR 1e-05
# train: jaccard: 0.350171, bce: 0.020851, dice: 0.503871, loss: 0.262361
# val: jaccard: 0.341654, bce: 0.019431, dice: 0.502627, loss: 0.261029
# 0m 2s
# Epoch 33/99
# ----------
# LR 1e-05
# train: jaccard: 0.348657, bce: 0.020917, dice: 0.504194, loss: 0.262555
# val: jaccard: 0.351250, bce: 0.019265, dice: 0.493833, loss: 0.256549
# saving best model
# 0m 2s
# Epoch 34/99
# ----------
# LR 1e-05
# train: jaccard: 0.360264, bce: 0.020695, dice: 0.495903, loss: 0.258299
# val: jaccard: 0.354668, bce: 0.019352, dice: 0.494103, loss: 0.256728
# 0m 2s
# Epoch 35/99
# ----------
# LR 1e-05
# train: jaccard: 0.364007, bce: 0.020708, dice: 0.494316, loss: 0.257512
# val: jaccard: 0.359697, bce: 0.019209, dice: 0.486552, loss: 0.252880
# saving best model
# 0m 2s
# Epoch 36/99
# ----------
# LR 1e-05
# train: jaccard: 0.365686, bce: 0.020715, dice: 0.488937, loss: 0.254826
# val: jaccard: 0.360728, bce: 0.019299, dice: 0.483707, loss: 0.251503
# saving best model
# 0m 2s
# Epoch 37/99
# ----------
# LR 1e-05
# train: jaccard: 0.368849, bce: 0.020796, dice: 0.485358, loss: 0.253077
# val: jaccard: 0.366986, bce: 0.019337, dice: 0.478936, loss: 0.249136
# saving best model
# 0m 2s
# Epoch 38/99
# ----------
# LR 1e-05
# train: jaccard: 0.374719, bce: 0.020842, dice: 0.482099, loss: 0.251471
# val: jaccard: 0.370210, bce: 0.019408, dice: 0.476166, loss: 0.247787
# saving best model
# 0m 2s
# Epoch 39/99
# ----------
# LR 1e-05
# train: jaccard: 0.377280, bce: 0.020901, dice: 0.478422, loss: 0.249662
# val: jaccard: 0.371229, bce: 0.019465, dice: 0.472528, loss: 0.245996
# saving best model
# 0m 2s
# Epoch 40/99
# ----------
# LR 1e-05
# train: jaccard: 0.378991, bce: 0.020985, dice: 0.475410, loss: 0.248197
# val: jaccard: 0.375826, bce: 0.019531, dice: 0.469103, loss: 0.244317
# saving best model
# 0m 2s
# Epoch 41/99
# ----------
# LR 1e-05
# train: jaccard: 0.384066, bce: 0.021066, dice: 0.472407, loss: 0.246736
# val: jaccard: 0.379339, bce: 0.019623, dice: 0.466569, loss: 0.243096
# saving best model
# 0m 2s
# Epoch 42/99
# ----------
# LR 1e-05
# train: jaccard: 0.386469, bce: 0.021164, dice: 0.470058, loss: 0.245611
# val: jaccard: 0.381543, bce: 0.019669, dice: 0.463648, loss: 0.241659
# saving best model
# 0m 2s
# Epoch 43/99
# ----------
# LR 1e-05
# train: jaccard: 0.388928, bce: 0.021226, dice: 0.467568, loss: 0.244397
# val: jaccard: 0.384823, bce: 0.019723, dice: 0.461181, loss: 0.240452
# saving best model
# 0m 2s
# Epoch 44/99
# ----------
# LR 1e-05
# train: jaccard: 0.392516, bce: 0.021305, dice: 0.465332, loss: 0.243318
# val: jaccard: 0.387140, bce: 0.019811, dice: 0.458798, loss: 0.239305
# saving best model
# 0m 2s
# Epoch 45/99
# ----------
# LR 1e-05
# train: jaccard: 0.393824, bce: 0.021437, dice: 0.463479, loss: 0.242458
# val: jaccard: 0.388698, bce: 0.019922, dice: 0.456404, loss: 0.238163
# saving best model
# 0m 2s
# Epoch 46/99
# ----------
# LR 1e-05
# train: jaccard: 0.396199, bce: 0.021559, dice: 0.461166, loss: 0.241362
# val: jaccard: 0.391194, bce: 0.020014, dice: 0.454205, loss: 0.237109
# saving best model
# 0m 2s
# Epoch 47/99
# ----------
# LR 1e-05
# train: jaccard: 0.398531, bce: 0.021647, dice: 0.459077, loss: 0.240362
# val: jaccard: 0.392455, bce: 0.020066, dice: 0.452111, loss: 0.236088
# saving best model
# 0m 2s
# Epoch 48/99
# ----------
# LR 1e-05
# train: jaccard: 0.399048, bce: 0.021707, dice: 0.457339, loss: 0.239523
# val: jaccard: 0.394881, bce: 0.020122, dice: 0.449952, loss: 0.235037
# saving best model
# 0m 2s
# Epoch 49/99
# ----------
# LR 1e-05
# train: jaccard: 0.402548, bce: 0.021802, dice: 0.455312, loss: 0.238557
# val: jaccard: 0.397728, bce: 0.020206, dice: 0.447891, loss: 0.234049
# saving best model
# 0m 2s
# Epoch 50/99
# ----------
# LR 1e-05
# train: jaccard: 0.403691, bce: 0.021872, dice: 0.453546, loss: 0.237709
# val: jaccard: 0.398603, bce: 0.020202, dice: 0.445876, loss: 0.233039
# saving best model
# 0m 2s
# Epoch 51/99
# ----------
# LR 1e-05
# train: jaccard: 0.405920, bce: 0.021856, dice: 0.451223, loss: 0.236540
# val: jaccard: 0.401783, bce: 0.020218, dice: 0.443984, loss: 0.232101
# saving best model
# 0m 2s
# Epoch 52/99
# ----------
# LR 1e-05
# train: jaccard: 0.408799, bce: 0.021914, dice: 0.449872, loss: 0.235893
# val: jaccard: 0.402541, bce: 0.020212, dice: 0.441752, loss: 0.230982
# saving best model
# 0m 2s
# Epoch 53/99
# ----------
# LR 1e-05
# train: jaccard: 0.408936, bce: 0.021907, dice: 0.447873, loss: 0.234890
# val: jaccard: 0.405216, bce: 0.020209, dice: 0.439343, loss: 0.229776
# saving best model
# 0m 2s
# Epoch 54/99
# ----------
# LR 1e-05
# train: jaccard: 0.412239, bce: 0.021925, dice: 0.445474, loss: 0.233700
# val: jaccard: 0.406891, bce: 0.020202, dice: 0.437262, loss: 0.228732
# saving best model
# 0m 2s
# Epoch 55/99
# ----------
# LR 1e-05
# train: jaccard: 0.412632, bce: 0.021881, dice: 0.444097, loss: 0.232989
# val: jaccard: 0.408899, bce: 0.020157, dice: 0.434988, loss: 0.227573
# saving best model
# 0m 2s
# Epoch 56/99
# ----------
# LR 1e-05
# train: jaccard: 0.416580, bce: 0.021895, dice: 0.441264, loss: 0.231580
# val: jaccard: 0.411523, bce: 0.020158, dice: 0.432531, loss: 0.226344
# saving best model
# 0m 2s
# Epoch 57/99
# ----------
# LR 1e-05
# train: jaccard: 0.418079, bce: 0.021844, dice: 0.439028, loss: 0.230436
# val: jaccard: 0.412847, bce: 0.020068, dice: 0.430413, loss: 0.225240
# saving best model
# 0m 2s
# Epoch 58/99
# ----------
# LR 1e-05
# train: jaccard: 0.419741, bce: 0.021799, dice: 0.436845, loss: 0.229322
# val: jaccard: 0.415031, bce: 0.020048, dice: 0.427795, loss: 0.223921
# saving best model
# 0m 2s
# Epoch 59/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.420906, bce: 0.021784, dice: 0.435223, loss: 0.228503
# val: jaccard: 0.415108, bce: 0.020029, dice: 0.427523, loss: 0.223776
# saving best model
# 0m 2s
# Epoch 60/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.421098, bce: 0.021763, dice: 0.434907, loss: 0.228335
# val: jaccard: 0.415135, bce: 0.020012, dice: 0.427367, loss: 0.223690
# saving best model
# 0m 2s
# Epoch 61/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.421258, bce: 0.021749, dice: 0.434644, loss: 0.228197
# val: jaccard: 0.415349, bce: 0.020005, dice: 0.427133, loss: 0.223569
# saving best model
# 0m 2s
# Epoch 62/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.421433, bce: 0.021744, dice: 0.434408, loss: 0.228076
# val: jaccard: 0.415624, bce: 0.020000, dice: 0.426854, loss: 0.223427
# saving best model
# 0m 2s
# Epoch 63/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.421732, bce: 0.021742, dice: 0.434166, loss: 0.227954
# val: jaccard: 0.415903, bce: 0.019997, dice: 0.426572, loss: 0.223284
# saving best model
# 0m 2s
# Epoch 64/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.421842, bce: 0.021742, dice: 0.433934, loss: 0.227838
# val: jaccard: 0.416208, bce: 0.019996, dice: 0.426265, loss: 0.223130
# saving best model
# 0m 2s
# Epoch 65/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.422454, bce: 0.021744, dice: 0.433677, loss: 0.227711
# val: jaccard: 0.416427, bce: 0.019995, dice: 0.425998, loss: 0.222996
# saving best model
# 0m 2s
# Epoch 66/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.422357, bce: 0.021739, dice: 0.433418, loss: 0.227578
# val: jaccard: 0.416563, bce: 0.019985, dice: 0.425779, loss: 0.222882
# saving best model
# 0m 2s
# Epoch 67/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.422594, bce: 0.021729, dice: 0.433179, loss: 0.227454
# val: jaccard: 0.416754, bce: 0.019975, dice: 0.425538, loss: 0.222757
# saving best model
# 0m 2s
# Epoch 68/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.422751, bce: 0.021722, dice: 0.432949, loss: 0.227335
# val: jaccard: 0.416956, bce: 0.019969, dice: 0.425282, loss: 0.222626
# saving best model
# 0m 2s
# Epoch 69/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.422994, bce: 0.021715, dice: 0.432721, loss: 0.227218
# val: jaccard: 0.417110, bce: 0.019959, dice: 0.425057, loss: 0.222508
# saving best model
# 0m 2s
# Epoch 70/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.423080, bce: 0.021710, dice: 0.432480, loss: 0.227095
# val: jaccard: 0.417352, bce: 0.019957, dice: 0.424769, loss: 0.222363
# saving best model
# 0m 2s
# Epoch 71/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.423285, bce: 0.021708, dice: 0.432217, loss: 0.226963
# val: jaccard: 0.417553, bce: 0.019954, dice: 0.424510, loss: 0.222232
# saving best model
# 0m 2s
# Epoch 72/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.423507, bce: 0.021707, dice: 0.431973, loss: 0.226840
# val: jaccard: 0.417778, bce: 0.019950, dice: 0.424234, loss: 0.222092
# saving best model
# 0m 2s
# Epoch 73/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.423795, bce: 0.021703, dice: 0.431744, loss: 0.226724
# val: jaccard: 0.417921, bce: 0.019943, dice: 0.424010, loss: 0.221977
# saving best model
# 0m 2s
# Epoch 74/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.423859, bce: 0.021698, dice: 0.431485, loss: 0.226591
# val: jaccard: 0.418153, bce: 0.019940, dice: 0.423735, loss: 0.221837
# saving best model
# 0m 2s
# Epoch 75/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.424157, bce: 0.021700, dice: 0.431272, loss: 0.226486
# val: jaccard: 0.418378, bce: 0.019936, dice: 0.423460, loss: 0.221698
# saving best model
# 0m 2s
# Epoch 76/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.424355, bce: 0.021690, dice: 0.431012, loss: 0.226351
# val: jaccard: 0.418523, bce: 0.019925, dice: 0.423244, loss: 0.221584
# saving best model
# 0m 2s
# Epoch 77/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.424431, bce: 0.021680, dice: 0.430794, loss: 0.226237
# val: jaccard: 0.418682, bce: 0.019916, dice: 0.423019, loss: 0.221468
# saving best model
# 0m 2s
# Epoch 78/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.424653, bce: 0.021677, dice: 0.430535, loss: 0.226106
# val: jaccard: 0.418963, bce: 0.019916, dice: 0.422697, loss: 0.221307
# saving best model
# 0m 2s
# Epoch 79/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.424794, bce: 0.021675, dice: 0.430286, loss: 0.225981
# val: jaccard: 0.419133, bce: 0.019908, dice: 0.422462, loss: 0.221185
# saving best model
# 0m 2s
# Epoch 80/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.425192, bce: 0.021673, dice: 0.430068, loss: 0.225871
# val: jaccard: 0.419378, bce: 0.019907, dice: 0.422161, loss: 0.221034
# saving best model
# 0m 2s
# Epoch 81/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.425099, bce: 0.021672, dice: 0.429804, loss: 0.225738
# val: jaccard: 0.419575, bce: 0.019900, dice: 0.421910, loss: 0.220905
# saving best model
# 0m 2s
# Epoch 82/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.425506, bce: 0.021661, dice: 0.429559, loss: 0.225610
# val: jaccard: 0.419689, bce: 0.019884, dice: 0.421725, loss: 0.220805
# saving best model
# 0m 2s
# Epoch 83/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.425573, bce: 0.021645, dice: 0.429334, loss: 0.225490
# val: jaccard: 0.419832, bce: 0.019872, dice: 0.421521, loss: 0.220696
# saving best model
# 0m 2s
# Epoch 84/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.425727, bce: 0.021641, dice: 0.429103, loss: 0.225372
# val: jaccard: 0.420123, bce: 0.019873, dice: 0.421192, loss: 0.220532
# saving best model
# 0m 2s
# Epoch 85/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.425943, bce: 0.021640, dice: 0.428836, loss: 0.225238
# val: jaccard: 0.420289, bce: 0.019867, dice: 0.420951, loss: 0.220409
# saving best model
# 0m 2s
# Epoch 86/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.426335, bce: 0.021634, dice: 0.428596, loss: 0.225115
# val: jaccard: 0.420492, bce: 0.019858, dice: 0.420694, loss: 0.220276
# saving best model
# 0m 2s
# Epoch 87/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.426278, bce: 0.021633, dice: 0.428366, loss: 0.225000
# val: jaccard: 0.420714, bce: 0.019859, dice: 0.420403, loss: 0.220131
# saving best model
# 0m 3s
# Epoch 88/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.426654, bce: 0.021632, dice: 0.428103, loss: 0.224868
# val: jaccard: 0.420905, bce: 0.019852, dice: 0.420153, loss: 0.220003
# saving best model
# 0m 2s
# Epoch 89/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426510, bce: 0.021628, dice: 0.427936, loss: 0.224782
# val: jaccard: 0.420924, bce: 0.019851, dice: 0.420128, loss: 0.219990
# saving best model
# 0m 2s
# Epoch 90/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426638, bce: 0.021627, dice: 0.427913, loss: 0.224770
# val: jaccard: 0.420934, bce: 0.019850, dice: 0.420109, loss: 0.219980
# saving best model
# 0m 2s
# Epoch 91/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426654, bce: 0.021626, dice: 0.427887, loss: 0.224757
# val: jaccard: 0.420951, bce: 0.019850, dice: 0.420085, loss: 0.219967
# saving best model
# 0m 2s
# Epoch 92/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426624, bce: 0.021625, dice: 0.427865, loss: 0.224745
# val: jaccard: 0.420963, bce: 0.019848, dice: 0.420066, loss: 0.219957
# saving best model
# 0m 2s
# Epoch 93/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426549, bce: 0.021624, dice: 0.427841, loss: 0.224732
# val: jaccard: 0.420979, bce: 0.019848, dice: 0.420042, loss: 0.219945
# saving best model
# 0m 2s
# Epoch 94/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426749, bce: 0.021623, dice: 0.427815, loss: 0.224719
# val: jaccard: 0.420994, bce: 0.019847, dice: 0.420020, loss: 0.219933
# saving best model
# 0m 2s
# Epoch 95/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426728, bce: 0.021622, dice: 0.427790, loss: 0.224706
# val: jaccard: 0.421013, bce: 0.019846, dice: 0.419994, loss: 0.219920
# saving best model
# 0m 2s
# Epoch 96/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426617, bce: 0.021621, dice: 0.427771, loss: 0.224696
# val: jaccard: 0.421025, bce: 0.019844, dice: 0.419976, loss: 0.219910
# saving best model
# 0m 2s
# Epoch 97/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426799, bce: 0.021620, dice: 0.427742, loss: 0.224681
# val: jaccard: 0.421043, bce: 0.019844, dice: 0.419950, loss: 0.219897
# saving best model
# 0m 2s
# Epoch 98/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426994, bce: 0.021620, dice: 0.427720, loss: 0.224670
# val: jaccard: 0.421070, bce: 0.019844, dice: 0.419918, loss: 0.219881
# saving best model
# 0m 2s
# Epoch 99/99
# ----------
# LR 1.0000000000000002e-07
# train: jaccard: 0.426764, bce: 0.021620, dice: 0.427693, loss: 0.224656
# val: jaccard: 0.421087, bce: 0.019843, dice: 0.419894, loss: 0.219869
# saving best model
# 0m 2s
# Best val loss: 0.219869
# test: jaccard: 0.412293, bce: 0.027839, dice: 0.429172, loss: 0.228506
# (3, 6, 192, 192)

# %% [markdown]
# ### Grading Rubric (Total: 10 Marks)
#
# The lab is graded based on the following criteria:
#
# 1. **Data Loading and Preparation (1 Mark)**
#    - Ensure reproducible results by setting seed to `27` before all randomized operations. (1 Mark)
#
# 2. **U-Net Architecture (4 Marks)**
#    - Uses appropriate U-Net Architecture to the problem with a full pipeline. (4 Marks)
#
# 3. **Hyperparameters Tuning (2 Marks)**
#    - Report evaluation metrics on validation set. (1 Mark)
#    - Analyzes results and tunes hyperparameters. (1 Mark)
#
# 4. **Model Evaluation and Understanding (3 Marks)**
#    - Reports Jaccard Index and Dice Scores for test set. (1 Mark)
#    - **Comparison amongst your peers.** Compares the model's performance against those of peers to identify strengths and areas for improvement. (2 Marks)
#
# Each section of the lab will be evaluated on completeness, and correctness in approach and analysis. Part of the rubric also includes the student's ability to explain and justify their choices and results.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed projects and wish you the best of luck!
