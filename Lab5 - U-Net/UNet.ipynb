# %% [markdown]
# ## Students Information
#
# Please enter the names and IDs of the two students below:
#
# 1. **Name**: [Norhan Reda Abdelwahed Ahmed]
#    **ID**: `9203639`
#
# 2. **Name**: [Hoda Gamal Hamouda Ismail]
#    **ID**: `9203673`
#
# 3. **Name**: [Samaa Hazem Mohamed Abdellatif]
#    **ID**: `9202660`
#
# 4. **Name**: [Shaza Mohamed AbdelRahman]
#    **ID**: `9161007`

# %% [markdown]
# ## Students Instructions
#
# This is your last graded lab assignment, as you put the work you have studied in the lectures in action, please take this opportunity to enhance your understanding of the concepts and hone your skills. As you work on your assignment, please keep the following instructions in mind:
#
# - Clearly state your personal information where indicated.
# - Be ready with your work before the time of the next discussion slot in the schedule.
# - Plagiarism will be met with penalties, refrain from copying any answers to make the most out of the assignment. If any signs of plagiarism are detected, actions will be taken.
# - It is acceptable to share the workload of the assignment bearing the discussion in mind.
# - Feel free to [reach out](mailto:cmpsy27@gmail.com) if there were any ambiguities or post on the classroom.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this assignment. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed assignments and wish you the best of luck!

# %% [markdown]
# ## Installation Instructions
#
# In this lab assignment, we require additional Python libraries for machine learning (ML) and deep learning (DL) algorithms and frameworks. To fulfill these requirements, we need to install Pytorch.
# 1. Install Pytorch \
# PyTorch is a versatile and powerful machine learning library for Python, known for its flexibility and ease of use in research and production. It supports various deep learning operations and models, including convolutional and recurrent neural networks. For Windows users, the installation also requires ensuring that CUDA, provided by NVIDIA, is compatible to enable GPU acceleration. This enhances performance significantly, particularly in training large neural networks.\
# For windows installation with GPU support you can [check out this link](https://pytorch.org/get-started/locally/) which is the source for the command below and please know that support for GPU is done for windows so you can also check out [previous versions](https://pytorch.org/get-started/previous-versions/), you could use CPU on windows smoothly, use linux or resort to [WSL](https://www.youtube.com/watch?v=R4m8YEixidI).
#
# ```bash
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# ```
# ```bash
# conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
# ```

# %% [markdown]
# > **Note:** You are allowed to install any other necessary libraries you deem useful for solving the lab. Please ensure that any additional libraries are compatible with the assignment requirements and are properly documented in your submission.

# %% [markdown]
# ## U-Net
#
# U-Net is a convolutional neural network designed specifically for biomedical image segmentation. First introduced in a 2015 paper by Olaf Ronneberger, Philipp Fischer, and Thomas Brox, its architecture is notably shaped like the letter "U", which inspired its name. This structure comprises a contracting path to capture context and a symmetrically expanding path that aids in precise localization, making it particularly adept at leveraging small datasets to achieve highly accurate segmentations. U-Net's ability to accurately segment various tissues and medical conditions has made it a staple in medical imaging and has spurred adaptations for broader image analysis applications. Its success in the medical domain demonstrates its potential for high-impact applications in other fields requiring detailed image segmentation.
#
# U-Net's robust architecture has found significant applications in the field of satellite imaging as well. The ability of U-Net to effectively handle multi-scale and high-resolution images makes it particularly suitable for satellite image analysis. In satellite imaging, U-Net is commonly used for tasks such as land cover classification, road detection, and building segmentation. Its structure allows for precise segmentation of complex objects from high-resolution satellite imagery, even with relatively limited labeled datasets. This capability is crucial in environmental monitoring, urban planning, and disaster management, where accurate and detailed image analysis is required. The adaptability and efficiency of U-Net in handling spatial hierarchies and various textures present in satellite images highlight its versatility and effectiveness beyond its initial medical context.

# %% [markdown]
# ### U-Net Architecture
#
# ![U-Net Architecture](unet.jpg)

# %% [markdown]
# ### Detailed Overview of Functions in `utilities.py`
#
# The `utilities.py` file contains multiple functions to support image processing, data manipulation, and neural network training:
#
# - **`generate_random_data(height, width, count)`**:
#   - Generates random images and masks.
#
# - **`generate_img_and_mask(height, width)`**:
#   - Generates a single image and corresponding mask.
#
# - **`add_square(img, mask)`**:
#   - Adds a square to an image and updates the mask.
#
# - **`add_filled_square(img, mask)`**:
#   - Adds a filled square to an image and updates the mask.
#
# - **`logical_and(mask1, mask2)`**:
#   - Performs logical 'AND' operation between two masks.
#
# - **`add_mesh_square(img, mask)`**:
#   - Adds a mesh-patterned square to an image and updates the mask.
#
# - **`add_triangle(img, mask)`**:
#   - Adds a triangle to an image and updates the mask.
#
# - **`add_circle(img, mask)`**:
#   - Adds a circle to an image and updates the mask.
#
# - **`add_plus(img, mask)`**:
#   - Adds a plus sign to an image and updates the mask.
#
# - **`get_random_location(shape, zoom)`**:
#   - Gets a random location within an image shape.
#
# - **`plot_img_array(img_array, n_col)`**:
#   - Plots an array of images.
#
# - **`plot_side_by_side(img_arrays)`**:
#   - Plots images side by side for comparison.
#
# - **`plot_errors(train_losses, val_losses)`**:
#   - Plots training and validation loss errors.
#
# - **`masks_to_colorimg(masks)`**:
#   - Converts masks to colored images.
#
# - **`generate_images_and_masks_then_plot()`**:
#   - Generates images and masks and plots them.
#
# - **`reverse_transform(transform)`**:
#   - Reverses a transformation applied to an image.
#
# - **`get_data_loaders(train_dir, valid_dir, batch_size)`**:
#   - Gets data loaders for training and validation datasets.
#
# - **`dice_loss(inputs, targets, smooth)`**:
#   - Calculates Dice loss for model evaluation.
#
# - **`calc_loss(pred, target, metrics)`**:
#   - Calculates loss and updates metrics.
#
# - **`print_metrics(metrics, epoch_samples, phase)`**:
#   - Prints metrics for training or validation phases.
#
# - **`train_model(model, dataloaders, criterion, optimizer, num_epochs)`**:
#   - Trains a model given data loaders and training parameters.
#
# - **`run(model)`**:
#   - Runs a full model training and evaluation session.
#
# - **`__init__`, `__len__`, `__getitem__`**:
#   - Standard class methods used in Python classes, typically for data handling or model initialization.
#
# These functions collectively facilitate the full lifecycle of processing, training, and evaluating neural network models, particularly focusing on image-related tasks.

# %% [markdown]
# The primary objective of this assignment is to develop a neural network model capable of performing accurate image segmentation. Image segmentation involves dividing an image into segments that represent different objects or regions, which is crucial in various applications such as medical imaging, autonomous driving, and satellite image analysis.
#
# #### Image and Mask Generation
# In this assignment, synthetic images along with corresponding segmentation masks are generated to train and evaluate the segmentation model. Each image typically includes multiple geometric shapes placed randomly. These shapes can include simple forms such as circles, squares, and triangles, or more complex designs.
#
# #### Masks and Their Role in Segmentation
# - **Mask Generation**: Alongside each synthetic image, a mask is generated where each shape in the image has a corresponding segment in the mask. Each segment in the mask is represented by a unique color or grayscale intensity, where each intensity level corresponds to a different class (shape).
# - **Function of the Mask**: The mask serves as a "ground truth" for training the segmentation model. The model learns to predict these masks from the input images. Essentially, the task of the model is to map the input image to its corresponding output mask, segmenting the shapes it has learned during training.
# - **Learning Process**: During training, the model adjusts its parameters to minimize the difference between its predicted masks and the ground truth masks. This process involves optimizing a loss function, typically using backpropagation.

# %% [markdown]
# ## Requirement - U-Net Application
# - **Implement or Use U-Net**:
#   - **Option 1: Implementation** - Students are encouraged to implement the U-Net architecture from scratch, including defining all the layers and connections based on the standard specifications found in the literature.
#   - **Option 2: Use Pre-existing Implementation** - Students may also opt to use an existing implementation of U-Net. This can include adapting an open-source model available in frameworks like PyTorch.
#
# - **Integration with `utilities.py`**:
#   - The U-Net model, whether self-implemented or pre-existing, must be integrated with the `utilities.py` script provided. This integration is essential for processing data, training the model, and evaluating its performance efficiently.
#   - The model should effectively process input images and produce accurate segmentation masks as output, corresponding to the different segments of the input images.
#   - **You can make any necessary modifications including writing your own training loop for example**.

# %%
# import libraries here
import torch
import torch.nn as nn
from torchvision import models
import utilities

# %%
class UNet(nn.Module):
    def __init__(self, n_classes):
        super(UNet, self).__init__()
        # TODO: Define needed layers, use n_class variable in the last layer.


        # Define the encoder layers
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.relu4 = nn.ReLU()
        self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv5 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.relu5 = nn.ReLU()
        self.conv6 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.relu6 = nn.ReLU()
        self.maxpool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv7 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.relu7 = nn.ReLU()
        self.conv8 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.relu8 = nn.ReLU()

        # Define the decoder layers
        self.upconv1 = nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2)
        self.conv9 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.relu9 = nn.ReLU()
        self.conv10 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.relu10 = nn.ReLU()

        self.upconv2 = nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2)
        self.conv11 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.relu11 = nn.ReLU()
        self.conv12 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.relu12 = nn.ReLU()

        self.upconv3 = nn.ConvTranspose2d(128, 64, kernel_size=2, stride=2)
        self.conv13 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.relu13 = nn.ReLU()
        self.conv14 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.relu14 = nn.ReLU()

        # Define the output layer
        self.conv15 = nn.Conv2d(64, n_classes, kernel_size=1)

    def forward(self, x):
        # Encoder
        out = self.conv1(x)
        out = self.relu1(out)
        out = self.conv2(out)
        out = self.relu2(out)
        out1 = out
        out = self.maxpool1(out)

        out = self.conv3(out)
        out = self.relu3(out)
        out = self.conv4(out)
        out = self.relu4(out)
        out2 = out
        out = self.maxpool2(out)

        out = self.conv5(out)
        out = self.relu5(out)
        out = self.conv6(out)
        out = self.relu6(out)
        out3 = out
        out = self.maxpool3(out)

        # Base convolutional layers
        out = self.conv7(out)
        out = self.relu7(out)
        out = self.conv8(out)
        out = self.relu8(out)

        # Decoder
        out = self.upconv1(out)
        out = torch.cat((out, out3), dim=1)
        out = self.conv9(out)
        out = self.relu9(out)
        out = self.conv10(out)
        out = self.relu10(out)

        out = self.upconv2(out)
        out = torch.cat((out, out2), dim=1)
        out = self.conv11(out)
        out = self.relu11(out)
        out = self.conv12(out)
        out = self.relu12(out)

        out = self.upconv3(out)
        out = torch.cat((out, out1), dim=1)
        out = self.conv13(out)
        out = self.relu13(out)
        out = self.conv14(out)
        out = self.relu14(out)

        out = self.conv15(out)

        return out

# %%
import utilities

# %%
utilities.run(UNet)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.995869, bce: 0.629533, dice: 0.990100, loss: 0.809817
# val: jaccard: 1.000000, bce: 0.176091, dice: 0.992576, loss: 0.584333
# saving best model
# 0m 22s
# Epoch 1/19
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.128903, dice: 0.991762, loss: 0.560332
# val: jaccard: 1.000000, bce: 0.030171, dice: 0.959905, loss: 0.495038
# saving best model
# 0m 21s
# Epoch 2/19
# ----------
# LR 0.001
# train: jaccard: 0.999817, bce: 0.025596, dice: 0.904961, loss: 0.465278
# val: jaccard: 0.994302, bce: 0.017537, dice: 0.833278, loss: 0.425408
# saving best model
# 0m 23s
# Epoch 3/19
# ----------
# LR 0.001
# train: jaccard: 0.945317, bce: 0.018483, dice: 0.814577, loss: 0.416530
# val: jaccard: 0.893589, bce: 0.016701, dice: 0.795853, loss: 0.406277
# saving best model
# 0m 29s
# Epoch 4/19
# ----------
# LR 0.001
# train: jaccard: 0.859260, bce: 0.018418, dice: 0.791355, loss: 0.404887
# val: jaccard: 0.830197, bce: 0.016700, dice: 0.777485, loss: 0.397093
# saving best model
# 0m 30s
# Epoch 5/19
# ----------
# LR 0.001
# train: jaccard: 0.801913, bce: 0.018367, dice: 0.771792, loss: 0.395080
# val: jaccard: 0.788203, bce: 0.017109, dice: 0.755816, loss: 0.386462
# saving best model
# 0m 28s
# Epoch 6/19
# ----------
# LR 0.001
# train: jaccard: 0.789233, bce: 0.018565, dice: 0.745677, loss: 0.382121
# val: jaccard: 0.788514, bce: 0.017740, dice: 0.724013, loss: 0.370877
# saving best model
# 0m 28s
# Epoch 7/19
# ----------
# LR 0.001
# train: jaccard: 0.760406, bce: 0.023782, dice: 0.703709, loss: 0.363745
# val: jaccard: 0.749224, bce: 0.030302, dice: 0.675173, loss: 0.352738
# saving best model
# 0m 29s
# Epoch 8/19
# ----------
# LR 0.001
# train: jaccard: 0.734302, bce: 0.031555, dice: 0.655060, loss: 0.343307
# val: jaccard: 0.732426, bce: 0.023131, dice: 0.636460, loss: 0.329796
# saving best model
# 0m 30s
# Epoch 9/19
# ----------
# LR 0.001
# train: jaccard: 0.697411, bce: 0.025203, dice: 0.599623, loss: 0.312413
# val: jaccard: 0.669942, bce: 0.024733, dice: 0.557066, loss: 0.290899
# saving best model
# 0m 30s
# Epoch 10/19
# ----------
# LR 0.001
# train: jaccard: 0.657884, bce: 0.025456, dice: 0.534433, loss: 0.279945
# val: jaccard: 0.629124, bce: 0.027701, dice: 0.502780, loss: 0.265240
# saving best model
# 0m 29s
# Epoch 11/19
# ----------
# LR 0.001
# train: jaccard: 0.615837, bce: 0.026663, dice: 0.483321, loss: 0.254992
# val: jaccard: 0.601898, bce: 0.025620, dice: 0.463327, loss: 0.244473
# saving best model
# 0m 28s
# Epoch 12/19
# ----------
# LR 0.001
# train: jaccard: 0.584079, bce: 0.027220, dice: 0.441150, loss: 0.234185
# val: jaccard: 0.568232, bce: 0.025683, dice: 0.422592, loss: 0.224138
# saving best model
# 0m 29s
# Epoch 13/19
# ----------
# LR 0.001
# train: jaccard: 0.560424, bce: 0.021924, dice: 0.408258, loss: 0.215091
# val: jaccard: 0.591885, bce: 0.026215, dice: 0.459292, loss: 0.242754
# 0m 29s
# Epoch 14/19
# ----------
# LR 0.001
# train: jaccard: 0.559284, bce: 0.027417, dice: 0.416702, loss: 0.222060
# val: jaccard: 0.579561, bce: 0.036642, dice: 0.395454, loss: 0.216048
# saving best model
# 0m 28s
# Epoch 15/19
# ----------
# LR 0.001
# train: jaccard: 0.551260, bce: 0.024800, dice: 0.380437, loss: 0.202619
# val: jaccard: 0.521878, bce: 0.027367, dice: 0.368053, loss: 0.197710
# saving best model
# 0m 29s
# Epoch 16/19
# ----------
# LR 0.001
# train: jaccard: 0.521071, bce: 0.028123, dice: 0.359357, loss: 0.193740
# val: jaccard: 0.532154, bce: 0.027854, dice: 0.356990, loss: 0.192422
# saving best model
# 0m 28s
# Epoch 17/19
# ----------
# LR 0.001
# train: jaccard: 0.511261, bce: 0.022413, dice: 0.348347, loss: 0.185380
# val: jaccard: 0.514515, bce: 0.021904, dice: 0.350648, loss: 0.186276
# saving best model
# 0m 29s
# Epoch 18/19
# ----------
# LR 0.001
# train: jaccard: 0.501106, bce: 0.019698, dice: 0.336876, loss: 0.178287
# val: jaccard: 0.502360, bce: 0.020041, dice: 0.331035, loss: 0.175538
# saving best model
# 0m 30s
# Epoch 19/19
# ----------
# LR 0.001
# train: jaccard: 0.498846, bce: 0.016443, dice: 0.336407, loss: 0.176425
# val: jaccard: 0.492190, bce: 0.018735, dice: 0.322886, loss: 0.170810
# saving best model
# 0m 29s
# Best val loss: 0.170810
# test: jaccard: 0.422262, bce: 0.011019, dice: 0.265428, loss: 0.138224
# (3, 6, 192, 192)

# %%
utilities.run(UNet,learn_rate=1e-3)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.997438, bce: 0.551194, dice: 0.990110, loss: 0.770652
# val: jaccard: 1.000000, bce: 0.048410, dice: 0.996336, loss: 0.522373
# saving best model
# 0m 28s
# Epoch 1/19
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.046653, dice: 0.987293, loss: 0.516973
# val: jaccard: 1.000000, bce: 0.019105, dice: 0.923732, loss: 0.471418
# saving best model
# 0m 18s
# Epoch 2/19
# ----------
# LR 0.001
# train: jaccard: 0.989592, bce: 0.019070, dice: 0.864654, loss: 0.441862
# val: jaccard: 0.936170, bce: 0.016471, dice: 0.807913, loss: 0.412192
# saving best model
# 0m 25s
# Epoch 3/19
# ----------
# LR 0.001
# train: jaccard: 0.896172, bce: 0.018214, dice: 0.801769, loss: 0.409991
# val: jaccard: 0.848098, bce: 0.016299, dice: 0.785136, loss: 0.400717
# saving best model
# 0m 30s
# Epoch 4/19
# ----------
# LR 0.001
# train: jaccard: 0.810938, bce: 0.018023, dice: 0.777826, loss: 0.397924
# val: jaccard: 0.784783, bce: 0.018375, dice: 0.763396, loss: 0.390886
# saving best model
# 0m 30s
# Epoch 5/19
# ----------
# LR 0.001
# train: jaccard: 0.794243, bce: 0.018835, dice: 0.754290, loss: 0.386562
# val: jaccard: 0.787701, bce: 0.018597, dice: 0.729026, loss: 0.373811
# saving best model
# 0m 30s
# Epoch 6/19
# ----------
# LR 0.001
# train: jaccard: 0.778760, bce: 0.022969, dice: 0.717646, loss: 0.370308
# val: jaccard: 0.784824, bce: 0.019062, dice: 0.697677, loss: 0.358370
# saving best model
# 0m 30s
# Epoch 7/19
# ----------
# LR 0.001
# train: jaccard: 0.780257, bce: 0.020334, dice: 0.697024, loss: 0.358679
# val: jaccard: 0.746613, bce: 0.019371, dice: 0.655062, loss: 0.337217
# saving best model
# 0m 31s
# Epoch 8/19
# ----------
# LR 0.001
# train: jaccard: 0.725345, bce: 0.023383, dice: 0.642447, loss: 0.332915
# val: jaccard: 0.708782, bce: 0.021217, dice: 0.609022, loss: 0.315120
# saving best model
# 0m 29s
# Epoch 9/19
# ----------
# LR 0.001
# train: jaccard: 0.683338, bce: 0.022468, dice: 0.588846, loss: 0.305657
# val: jaccard: 0.654456, bce: 0.021648, dice: 0.549920, loss: 0.285784
# saving best model
# 0m 29s
# Epoch 10/19
# ----------
# LR 0.001
# train: jaccard: 0.640893, bce: 0.024746, dice: 0.530749, loss: 0.277747
# val: jaccard: 0.651431, bce: 0.026583, dice: 0.499232, loss: 0.262908
# saving best model
# 0m 30s
# Epoch 11/19
# ----------
# LR 0.001
# train: jaccard: 0.633614, bce: 0.027601, dice: 0.494458, loss: 0.261030
# val: jaccard: 0.630118, bce: 0.024732, dice: 0.470903, loss: 0.247817
# saving best model
# 0m 29s
# Epoch 12/19
# ----------
# LR 0.001
# train: jaccard: 0.639064, bce: 0.026644, dice: 0.472731, loss: 0.249688
# val: jaccard: 0.616140, bce: 0.021951, dice: 0.460753, loss: 0.241352
# saving best model
# 0m 30s
# Epoch 13/19
# ----------
# LR 0.001
# train: jaccard: 0.609744, bce: 0.022477, dice: 0.456279, loss: 0.239378
# val: jaccard: 0.619257, bce: 0.022474, dice: 0.441783, loss: 0.232129
# saving best model
# 0m 29s
# Epoch 14/19
# ----------
# LR 0.001
# train: jaccard: 0.613025, bce: 0.025349, dice: 0.436389, loss: 0.230869
# val: jaccard: 0.603876, bce: 0.024803, dice: 0.433525, loss: 0.229164
# saving best model
# 0m 28s
# Epoch 15/19
# ----------
# LR 0.001
# train: jaccard: 0.599942, bce: 0.024335, dice: 0.424913, loss: 0.224624
# val: jaccard: 0.600257, bce: 0.020807, dice: 0.426836, loss: 0.223822
# saving best model
# 0m 30s
# Epoch 16/19
# ----------
# LR 0.001
# train: jaccard: 0.582487, bce: 0.021127, dice: 0.415899, loss: 0.218513
# val: jaccard: 0.573907, bce: 0.020023, dice: 0.407366, loss: 0.213695
# saving best model
# 0m 29s
# Epoch 17/19
# ----------
# LR 0.001
# train: jaccard: 0.561558, bce: 0.019206, dice: 0.396049, loss: 0.207627
# val: jaccard: 0.562099, bce: 0.023478, dice: 0.383395, loss: 0.203437
# saving best model
# 0m 29s
# Epoch 18/19
# ----------
# LR 0.001
# train: jaccard: 0.554833, bce: 0.026189, dice: 0.375873, loss: 0.201031
# val: jaccard: 0.551622, bce: 0.026600, dice: 0.375118, loss: 0.200859
# saving best model
# 0m 29s
# Epoch 19/19
# ----------
# LR 0.001
# train: jaccard: 0.540962, bce: 0.026498, dice: 0.358278, loss: 0.192388
# val: jaccard: 0.550666, bce: 0.022015, dice: 0.357541, loss: 0.189778
# saving best model
# 0m 30s
# Best val loss: 0.189778
# test: jaccard: 0.539685, bce: 0.025156, dice: 0.327034, loss: 0.176095
# (3, 6, 192, 192)

# %%
utilities.run(UNet,learn_rate=1e-2)
# Out:
# Epoch 0/19
# ----------
# LR 0.01
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.997789, bce: 11.015171, dice: 0.991544, loss: 6.003358
# val: jaccard: 0.994685, bce: 13814.747070, dice: 0.990076, loss: 6907.868652
# saving best model
# 0m 20s
# Epoch 1/19
# ----------
# LR 0.01
# train: jaccard: 0.997236, bce: 41770.327119, dice: 0.991957, loss: 20885.658908
# val: jaccard: 0.995096, bce: 0.585473, dice: 0.991108, loss: 0.788291
# saving best model
# 0m 25s
# Epoch 2/19
# ----------
# LR 0.01
# train: jaccard: 0.994766, bce: 2.021243, dice: 0.990530, loss: 1.505886
# val: jaccard: 0.995787, bce: 0.618262, dice: 0.990556, loss: 0.804409
# 0m 29s
# Epoch 3/19
# ----------
# LR 0.01
# train: jaccard: 0.996686, bce: 269530.005082, dice: 0.989200, loss: 134765.498286
# val: jaccard: 1.000000, bce: 0.631839, dice: 0.990982, loss: 0.811410
# 0m 25s
# Epoch 4/19
# ----------
# LR 0.01
# train: jaccard: 1.000000, bce: 0.624515, dice: 0.990118, loss: 0.807317
# val: jaccard: 1.000000, bce: 0.611323, dice: 0.990983, loss: 0.801153
# 0m 18s
# Epoch 5/19
# ----------
# LR 0.01
# train: jaccard: 1.000000, bce: 0.603279, dice: 0.990121, loss: 0.796700
# val: jaccard: 1.000000, bce: 0.589558, dice: 0.990985, loss: 0.790272
# 0m 19s
# Epoch 6/19
# ----------
# LR 0.01
# train: jaccard: 1.000000, bce: 0.581153, dice: 0.990124, loss: 0.785639
# val: jaccard: 1.000000, bce: 0.566351, dice: 0.990987, loss: 0.778669
# saving best model
# 0m 18s
# Epoch 7/19
# ----------
# LR 0.01
# train: jaccard: 1.000000, bce: 0.557191, dice: 0.990127, loss: 0.773659
# val: jaccard: 1.000000, bce: 0.541110, dice: 0.990990, loss: 0.766050
# saving best model
# 0m 19s
# Epoch 8/19
# ----------
# LR 0.01
# train: jaccard: 1.000000, bce: 0
# ----------
# LR 0.0001
# train: jaccard: 0.688982, bce: 0.028139, dice: 0.575933, loss: 0.302036
# val: jaccard: 0.692909, bce: 0.025997, dice: 0.574044, loss: 0.300020
# saving best model
# 0m 30s
# Epoch 15/19
# ----------
# LR 0.0001
# train: jaccard: 0.683684, bce: 0.027625, dice: 0.568446, loss: 0.298035
# val: jaccard: 0.690861, bce: 0.026204, dice: 0.565283, loss: 0.295744
# saving best model
# 0m 29s
# Epoch 16/19
# ----------
# LR 0.0001
# train: jaccard: 0.681699, bce: 0.027982, dice: 0.559893, loss: 0.293937
# val: jaccard: 0.686998, bce: 0.026701, dice: 0.556034, loss: 0.291367
# saving best model
# 0m 29s
# Epoch 17/19
# ----------
# LR 0.0001
# train: jaccard: 0.677727, bce: 0.028513, dice: 0.550960, loss: 0.289736
# val: jaccard: 0.683453, bce: 0.027120, dice: 0.546947, loss: 0.287033
# saving best model
# 0m 31s
# Epoch 18/19
# ----------
# LR 0.0001
# train: jaccard: 0.674207, bce: 0.028821, dice: 0.542295, loss: 0.285558
# val: jaccard: 0.679671, bce: 0.027227, dice: 0.538369, loss: 0.282798
# saving best model
# 0m 29s
# Epoch 19/19
# ----------
# LR 1e-05
# train: jaccard: 0.671221, bce: 0.028851, dice: 0.536506, loss: 0.282679
# val: jaccard: 0.679407, bce: 0.027254, dice: 0.537478, loss: 0.282366
# saving best model
# 0m 30s
# Best val loss: 0.282366
# test: jaccard: 0.685757, bce: 0.035534, dice: 0.533572, loss: 0.284553
# (3, 6, 192, 192)

# %%
utilities.run(UNet,stp_size=20)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.986936, bce: 0.628072, dice: 0.990231, loss: 0.809152
# val: jaccard: 1.000000, bce: 0.278592, dice: 0.992906, loss: 0.635749
# saving best model
# 0m 28s
# Epoch 1/19
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.132340, dice: 0.993810, loss: 0.563075
# val: jaccard: 1.000000, bce: 0.028647, dice: 0.980137, loss: 0.504392
# saving best model
# 0m 25s
# Epoch 2/19
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.025575, dice: 0.926549, loss: 0.476062
# val: jaccard: 1.000000, bce: 0.017374, dice: 0.841119, loss: 0.429246
# saving best model
# 0m 19s
# Epoch 3/19
# ----------
# LR 0.001
# train: jaccard: 0.980450, bce: 0.018820, dice: 0.821104, loss: 0.419962
# val: jaccard: 0.853370, bce: 0.017173, dice: 0.800057, loss: 0.408615
# saving best model
# 0m 23s
# Epoch 4/19
# ----------
# LR 0.001
# train: jaccard: 0.857299, bce: 0.018924, dice: 0.795973, loss: 0.407448
# val: jaccard: 0.836998, bce: 0.016463, dice: 0.779357, loss: 0.397910
# saving best model
# 0m 29s
# Epoch 5/19
# ----------
# LR 0.001
# train: jaccard: 0.867712, bce: 0.019176, dice: 0.789578, loss: 0.404377
# val: jaccard: 0.801256, bce: 0.016799, dice: 0.755418, loss: 0.386108
# saving best model
# 0m 30s
# Epoch 6/19
# ----------
# LR 0.001
# train: jaccard: 0.798713, bce: 0.018549, dice: 0.751230, loss: 0.384889
# val: jaccard: 0.792701, bce: 0.017930, dice: 0.736321, loss: 0.377125
# saving best model
# 0m 28s
# Epoch 7/19
# ----------
# LR 0.001
# train: jaccard: 0.793188, bce: 0.020979, dice: 0.723768, loss: 0.372373
# val: jaccard: 0.785821, bce: 0.021801, dice: 0.706287, loss: 0.364044
# saving best model
# 0m 29s
# Epoch 8/19
# ----------
# LR 0.001
# train: jaccard: 0.774932, bce: 0.024395, dice: 0.690527, loss: 0.357461
# val: jaccard: 0.763136, bce: 0.022887, dice: 0.672826, loss: 0.347856
# saving best model
# 0m 30s
# Epoch 9/19
# ----------
# LR 0.001
# train: jaccard: 0.742424, bce: 0.024899, dice: 0.651023, loss: 0.337961
# val: jaccard: 0.725758, bce: 0.024229, dice: 0.626835, loss: 0.325532
# saving best model
# 0m 29s
# Epoch 10/19
# ----------
# LR 0.001
# train: jaccard: 0.713403, bce: 0.028979, dice: 0.598869, loss: 0.313924
# val: jaccard: 0.711553, bce: 0.030721, dice: 0.567563, loss: 0.299142
# saving best model
# 0m 28s
# Epoch 11/19
# ----------
# LR 0.001
# train: jaccard: 0.688465, bce: 0.032633, dice: 0.545597, loss: 0.289115
# val: jaccard: 0.687726, bce: 0.032116, dice: 0.519413, loss: 0.275764
# saving best model
# 0m 29s
# Epoch 12/19
# ----------
# LR 0.001
# train: jaccard: 0.673848, bce: 0.030167, dice: 0.503319, loss: 0.266743
# val: jaccard: 0.673838, bce: 0.022339, dice: 0.522173, loss: 0.272256
# saving best model
# 0m 29s
# Epoch 13/19
# ----------
# LR 0.001
# train: jaccard: 0.678937, bce: 0.030767, dice: 0.510307, loss: 0.270537
# val: jaccard: 0.667358, bce: 0.029305, dice: 0.482679, loss: 0.255992
# saving best model
# 0m 29s
# Epoch 14/19
# ----------
# LR 0.001
# train: jaccard: 0.650421, bce: 0.025561, dice: 0.483668, loss: 0.254614
# val: jaccard: 0.630868, bce: 0.019980, dice: 0.491354, loss: 0.255667
# saving best model
# 0m 28s
# Epoch 15/19
# ----------
# LR 0.001
# train: jaccard: 0.624837, bce: 0.020260, dice: 0.473563, loss: 0.246912
# val: jaccard: 0.629247, bce: 0.021775, dice: 0.450877, loss: 0.236326
# saving best model
# 0m 29s
# Epoch 16/19
# ----------
# LR 0.001
# train: jaccard: 0.620967, bce: 0.021605, dice: 0.449285, loss: 0.235445
# val: jaccard: 0.606789, bce: 0.021693, dice: 0.453958, loss: 0.237825
# 0m 30s
# Epoch 17/19
# ----------
# LR 0.001
# train: jaccard: 0.595907, bce: 0.021998, dice: 0.441700, loss: 0.231849
# val: jaccard: 0.606436, bce: 0.024604, dice: 0.430864, loss: 0.227734
# saving best model
# 0m 29s
# Epoch 18/19
# ----------
# LR 0.001
# train: jaccard: 0.590448, bce: 0.028602, dice: 0.418776, loss: 0.223689
# val: jaccard: 0.575662, bce: 0.036888, dice: 0.397612, loss: 0.217250
# saving best model
# 0m 28s
# Epoch 19/19
# ----------
# LR 0.0001
# train: jaccard: 0.572586, bce: 0.034524, dice: 0.401073, loss: 0.217799
# val: jaccard: 0.572193, bce: 0.027700, dice: 0.402506, loss: 0.215103
# saving best model
# 0m 29s
# Best val loss: 0.215103
# test: jaccard: 0.590121, bce: 0.038507, dice: 0.384306, loss: 0.211407
# (3, 6, 192, 192)

# %%
utilities.run(UNet,stp_size=30)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train
# saving best model
# 0m 29s
# Epoch 13/19
# ----------
# LR 0.001
# train: jaccard: 0.594088, bce: 0.028483, dice: 0.438471, loss: 0.233477
# val: jaccard: 0.597786, bce: 0.029847, dice: 0.440101, loss: 0.234974
# saving best model
# 0m 29s
# Epoch 14/19
# ----------
# LR 0.001
# train: jaccard: 0.580410, bce: 0.035745, dice: 0.428129, loss: 0.231937
# val: jaccard: 0.595215, bce: 0.060237, dice: 0.415544, loss: 0.237890
# 0m 29s
# Epoch 15/19
# ----------
# LR 0.001
# train: jaccard: 0.587937, bce: 0.045937, dice: 0.426934, loss: 0.236436
# val: jaccard: 0.584260, bce: 0.026445, dice: 0.424847, loss: 0.225646
# saving best model
# 0m 30s
# Epoch 16/19
# ----------
# LR 0.001
# train: jaccard: 0.572474, bce: 0.030546, dice: 0.415125, loss: 0.222836
# val: jaccard: 0.573202, bce: 0.035058, dice: 0.408462, loss: 0.221760
# saving best model
# 0m 28s
# Epoch 17/19
# ----------
# LR 0.001
# train: jaccard: 0.561105, bce: 0.034044, dice: 0.399682, loss: 0.216863
# val: jaccard: 0.574948, bce: 0.034136, dice: 0.392406, loss: 0.213271
# saving best model
# 0m 29s
# Epoch 18/19
# ----------
# LR 0.001
# train: jaccard: 0.559797, bce: 0.030708, dice: 0.391122, loss: 0.210915
# val: jaccard: 0.564775, bce: 0.027888, dice: 0.392103, loss: 0.209995
# saving best model
# 0m 30s
# Epoch 19/19
# ----------
# LR 0.001
# train: jaccard: 0.544764, bce: 0.026413, dice: 0.379656, loss: 0.203035
# val: jaccard: 0.548739, bce: 0.022625, dice: 0.379870, loss: 0.201248
# saving best model
# 0m 29s
# Best val loss: 0.201248
# test: jaccard: 0.551990, bce: 0.025951, dice: 0.362214, loss: 0.194083
# (3, 6, 192, 192)

# %%
utilities.run(UNet,gma=0.1)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.997846, bce: 0.559076, dice: 0.991003, loss: 0.775040
# val: jaccard: 1.000000, bce: 0.186622, dice: 0.993365, loss: 0.589994
# saving best model
# 0m 25s
# Epoch 1/19
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.085023, dice: 0.986808, loss: 0.535916
# val: jaccard: 1.000000, bce: 0.024809, dice: 0.940359, loss: 0.482584
# saving best model
# 0m 19s
# Epoch 2/19
# ----------
# LR 0.001
# train: jaccard: 0.992850, bce: 0.021578, dice: 0.885798, loss: 0.453688
# val: jaccard: 0.929185, bce: 0.016930, dice: 0.817108, loss: 0.417019
# saving best model
# 0m 23s
# Epoch 3/19
# ----------
# LR 0.001
# train: jaccard: 0.902607, bce: 0.018775, dice: 0.804330, loss: 0.411552
# val: jaccard: 0.888503, bce: 0.016960, dice: 0.785084, loss: 0.401022
# saving best model
# 0m 29s
# Epoch 4/19
# ----------
# LR 0.001
# train: jaccard: 0.863971, bce: 0.018961, dice: 0.777865, loss: 0.398413
# val: jaccard: 0.831094, bce: 0.019461, dice: 0.764649, loss: 0.392055
# saving best model
# 0m 29s
# Epoch 5/19
# ----------
# LR 0.001
# val: jaccard: 0.710954, bce: 0.027167, dice: 0.611259, loss: 0.319213
# 0m 30s
# Epoch 19/19
# ----------
# LR 0.001
# train: jaccard: 0.695875, bce: 0.026581, dice: 0.573506, loss: 0.300044
# val: jaccard: 0.643168, bce: 0.019468, dice: 0.511582, loss: 0.265525
# 0m 29s
# Best val loss: 0.264396
# test: jaccard: 0.644057, bce: 0.033627, dice: 0.502796, loss: 0.268212
# (3, 6, 192, 192)

# %%
utilities.run(UNet,gma=0.5)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.982625, bce: 0.579882, dice: 0.990085, loss: 0.784984
# val: jaccard: 1.000000, bce: 0.056243, dice: 0.995907, loss: 0.526075
# saving best model
# 0m 26s
# Epoch 1/19
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.116484, dice: 0.985807, loss: 0.551146
# val: jaccard: 1.000000, bce: 0.035669, dice: 0.939549, loss: 0.487609
# saving best model
# 0m 19s
# Epoch 2/19
# ----------
# LR 0.001
# train: jaccard: 0.951131, bce: 0.027654, dice: 0.889651, loss: 0.458652
# val: jaccard: 0.910757, bce: 0.016492, dice: 0.818802, loss: 0.417647
# saving best model
# 0m 28s
# Epoch 3/19
# ----------
# LR 0.001
# train: jaccard: 0.889591, bce: 0.017921, dice: 0.803498, loss: 0.410709
# val: jaccard: 0.856000, bce: 0.016110, dice: 0.783214, loss: 0.399662
# saving best model
# 0m 29s
# Epoch 4/19
# ----------
# LR 0.001
# train: jaccard: 0.829540, bce: 0.017534, dice: 0.777556, loss: 0.397545
# val: jaccard: 0.812301, bce: 0.016600, dice: 0.758227, loss: 0.387414
# saving best model
# 0m 30s
# Epoch 5/19
# ----------
# LR 0.001
# train: jaccard: 0.818808, bce: 0.018554, dice: 0.748326, loss: 0.383440
# val: jaccard: 0.766196, bce: 0.016320, dice: 0.719810, loss: 0.368065
# saving best model
# 0m 29s
# Epoch 6/19
# ----------
# LR 0.001
# train: jaccard: 0.783673, bce: 0.018543, dice: 0.710186, loss: 0.364365
# val: jaccard: 0.742179, bce: 0.021014, dice: 0.679633, loss: 0.350324
# saving best model
# 0m 29s
# Epoch 7/19
# ----------
# LR 0.001
# train: jaccard: 0.721056, bce: 0.023843, dice: 0.663162, loss: 0.343503
# val: jaccard: 0.701333, bce: 0.021296, dice: 0.629211, loss: 0.325253
# saving best model
# 0m 31s
# Epoch 8/19
# ----------
# LR 0.001
# train: jaccard: 0.682003, bce: 0.024209, dice: 0.599352, loss: 0.311781
# val: jaccard: 0.666745, bce: 0.025737, dice: 0.544604, loss: 0.285171
# saving best model
# 0m 29s
# Epoch 9/19
# ----------
# LR 0.001
# train: jaccard: 0.645252, bce: 0.027593, dice: 0.513969, loss: 0.270781
# val: jaccard: 0.624337, bce: 0.025494, dice: 0.487941, loss: 0.256718
# saving best model
# 0m 30s
# Epoch 10/19
# ----------
# LR 0.001
# train: jaccard: 0.622730, bce: 0.028258, dice: 0.471724, loss: 0.249991
# val: jaccard: 0.613578, bce: 0.025469, dice: 0.454789, loss: 0.240129
# saving best model
# 0m 30s
# Epoch 11/19
# ----------
# LR 0.001
# train: jaccard: 0.612384, bce: 0.027772, dice: 0.448189, loss: 0.237980
# val: jaccard: 0.609063, bce: 0.025319, dice: 0.460174, loss: 0.242747
# 0m 30s
# Epoch 12/19
# ----------
# LR 0.001
# train: jaccard: 0.601808, bce: 0.027276, dice: 0.439376, loss: 0.233326
# val: jaccard: 0.608503, bce: 0.025843, dice: 0.432698, loss: 0.229270
# saving best model
# 0m 29s
# Epoch 13/19
# ----------
# LR 0.001
# train: jaccard: 0.599508, bce: 0.026841, dice: 0.427211, loss: 0.227026
# val: jaccard: 0.598160, bce: 0.023741, dice: 0.425842, loss: 0.224792
# saving best model
# 0m 29s
# Epoch 14/19
# ----------
# LR 0.001
# train: jaccard: 0.587145, bce: 0.024218, dice: 0.421541, loss: 0.222880
# val: jaccard: 0.596477, bce: 0.024599, dice: 0.413014, loss: 0.218807
# saving best model
# 0m 30s
# Epoch 15/19
# ----------
# LR 0.001
# train: jaccard: 0.578977, bce: 0.024158, dice: 0.411569, loss: 0.217863
# val: jaccard: 0.572045, bce: 0.022159, dice: 0.404626, loss: 0.213393
# saving best model
# 0m 29s
# Epoch 16/19
# ----------
# LR 0.001
# train: jaccard: 0.560647, bce: 0.021816, dice: 0.400040, loss: 0.210928
# val: jaccard: 0.567219, bce: 0.020932, dice: 0.400490, loss: 0.210711
# saving best model
# 0m 30s
# Epoch 17/19
# ----------
# LR 0.001
# train: jaccard: 0.556040, bce: 0.021860, dice: 0.387382, loss: 0.204621
# val: jaccard: 0.551854, bce: 0.020635, dice: 0.378876, loss: 0.199756
# saving best model
# 0m 29s
# Epoch 18/19
# ----------
# LR 0.001
# train: jaccard: 0.534677, bce: 0.018621, dice: 0.368331, loss: 0.193476
# val: jaccard: 0.543444, bce: 0.017403, dice: 0.364201, loss: 0.190802
# saving best model
# 0m 29s
# Epoch 19/19
# ----------
# LR 0.001
# train: jaccard: 0.540040, bce: 0.018131, dice: 0.364928, loss: 0.191529
# val: jaccard: 0.529678, bce: 0.017318, dice: 0.357795, loss: 0.187557
# saving best model
# 0m 30s
# Best val loss: 0.187557
# test: jaccard: 0.519407, bce: 0.017287, dice: 0.322530, loss: 0.169909
# (3, 6, 192, 192)

# %%
utilities.run(UNet,gma=0.9)
# Out:
# Epoch 0/19
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.997246, bce: 0.531076, dice: 0.990389, loss: 0.760733
# val: jaccard: 1.000000, bce: 0.052931, dice: 0.995086, loss: 0.524009
# saving best model
# 0m 28s
# Epoch 1/19
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.044365, dice: 0.983451, loss: 0.513908
# val: jaccard: 1.000000, bce: 0.019402, dice: 0.901683, loss: 0.460542
# saving best model
# 0m 20s
# Epoch 2/19
# ----------
# LR 0.001
# train: jaccard: 0.976475, bce: 0.019442, dice: 0.849860, loss: 0.434651
# val: jaccard: 0.876036, bce: 0.016737, dice: 0.801274, loss: 0.409005
# saving best model
# 0m 23s
# Epoch 3/19
# ----------
# LR 0.001
# train: jaccard: 0.848482, bce: 0.018213, dice: 0.792412, loss: 0.405313
# val: jaccard: 0.813094, bce: 0.017700, dice: 0.774762, loss: 0.396231
# saving best model
# 0m 30s
# Epoch 4/19
# ----------
# LR 0.001
# train: jaccard: 0.804393, bce: 0.018777, dice: 0.766033, loss: 0.392405
# val: jaccard: 0.802249, bce: 0.017127, dice: 0.746242, loss: 0.381684
# saving best model
# 0m 30s
# Epoch 5/19
# ----------
# LR 0.001
# train: jaccard: 0.789532, bce: 0.019242, dice: 0.728144, loss: 0.373693
# val: jaccard: 0.750445, bce: 0.019166, dice: 0.694644, loss: 0.356905
# saving best model
# 0m 29s
# Epoch 6/19
# ----------
# LR 0.001
# train: jaccard: 0.738504, bce: 0.023464, dice: 0.664899, loss: 0.344182
# val: jaccard: 0.748715, bce: 0.029435, dice: 0.627054, loss: 0.328244
# saving best model
# 0m 29s
# Epoch 7/19
# ----------
# LR 0.001
# train: jaccard: 0.730231, bce: 0.033731, dice: 0.596649, loss: 0.315190
# val: jaccard: 0.714430, bce: 0.029452, dice: 0.569643, loss: 0.299548
# saving best model
# 0m 29s
# Epoch 8/19
# ----------
# LR 0.001
# train: jaccard: 0.698305, bce: 0.030141, dice: 0.551479, loss: 0.290810
# val: jaccard: 0.700575, bce: 0.030171, dice: 0.528320, loss: 0.279246
# saving best model
# 0m 29s
# Epoch 9/19
# ----------
# LR 0.001
# train: jaccard: 0.681101, bce: 0.029002, dice: 0.512315, loss: 0.270658
# val: jaccard: 0.686479, bce: 0.024786, dice: 0.499240, loss: 0.262013
# saving best model
# 0m 31s
# Epoch 10/19
# ----------
# LR 0.001
# train: jaccard: 0.653860, bce: 0.022478, dice: 0.479485, loss: 0.250982
# val: jaccard: 0.626080, bce: 0.019874, dice: 0.453586, loss: 0.236730
# saving best model
# 0m 30s
# Epoch 11/19
# ----------
# LR 0.001
# train: jaccard: 0.611070, bce: 0.022596, dice: 0.446215, loss: 0.234405
# val: jaccard: 0.610086, bce: 0.024690, dice: 0.441433, loss: 0.233061
# saving best model
# 0m 29s
# Epoch 12/19
# ----------
# LR 0.001
# train: jaccard: 0.595549, bce: 0.025112, dice: 0.430072, loss: 0.227592
# val: jaccard: 0.592450, bce: 0.024995, dice: 0.424819, loss: 0.224907
# saving best model
# 0m 28s
# Epoch 13/19
# ----------
# LR 0.001
# train: jaccard: 0.602041, bce: 0.026943, dice: 0.427466, loss: 0.227204
# val: jaccard: 0.584255, bce: 0.026211, dice: 0.410892, loss: 0.218552
# saving best model
# 0m 29s
# Epoch 14/19
# ----------
# LR 0.001
# train: jaccard: 0.580890, bce: 0.026107, dice: 0.408381, loss: 0.217244
# val: jaccard: 0.567084, bce: 0.021643, dice: 0.393740, loss: 0.207691
# saving best model
# 0m 30s
# Epoch 15/19
# ----------
# LR 0.001
# train: jaccard: 0.564666, bce: 0.020976, dice: 0.398648, loss: 0.209812
# val: jaccard: 0.567770, bce: 0.019717, dice: 0.396029, loss: 0.207873
# 0m 30s
# Epoch 16/19
# ----------
# LR 0.001
# train: jaccard: 0.555957, bce: 0.019092, dice: 0.385706, loss: 0.202399
# val: jaccard: 0.552155, bce: 0.019615, dice: 0.389657, loss: 0.204636
# saving best model
# 0m 31s
# Epoch 17/19
# ----------
# LR 0.001
# train: jaccard: 0.566628, bce: 0.020777, dice: 0.390177, loss: 0.205477
# val: jaccard: 0.551621, bce: 0.019337, dice: 0.371832, loss: 0.195585
# saving best model
# 0m 30s
# Epoch 18/19
# ----------
# LR 0.001
# train: jaccard: 0.544938, bce: 0.017654, dice: 0.371345, loss: 0.194500
# val: jaccard: 0.533331, bce: 0.014701, dice: 0.372303, loss: 0.193502
# saving best model
# 0m 29s
# Epoch 19/19
# ----------
# LR 0.001
# train: jaccard: 0.520841, bce: 0.015011, dice: 0.350840, loss: 0.182926
# val: jaccard: 0.539961, bce: 0.017535, dice: 0.362094, loss: 0.189815
# saving best model
# 0m 31s
# Best val loss: 0.189815
# test: jaccard: 0.525894, bce: 0.018007, dice: 0.325556, loss: 0.171781
# (3, 6, 192, 192)

# %%
utilities.run(UNet,epochs=60)
# Out:
# Epoch 0/59
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.978114, bce: 0.612200, dice: 0.990310, loss: 0.801255
# val: jaccard: 0.971912, bce: 0.271622, dice: 0.994187, loss: 0.632905
# saving best model
# 0m 31s
# Epoch 1/59
# ----------
# LR 0.001
# train: jaccard: 0.992002, bce: 0.136834, dice: 0.993936, loss: 0.565385
# val: jaccard: 1.000000, bce: 0.029743, dice: 0.985421, loss: 0.507582
# saving best model
# 0m 21s
# Epoch 2/59
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.026025, dice: 0.949613, loss: 0.487819
# val: jaccard: 1.000000, bce: 0.017806, dice: 0.878888, loss: 0.448347
# saving best model
# 0m 20s
# Epoch 3/59
# ----------
# LR 0.001
# train: jaccard: 0.984191, bce: 0.018456, dice: 0.839969, loss: 0.429212
# val: jaccard: 0.922499, bce: 0.016395, dice: 0.794583, loss: 0.405489
# saving best model
# 0m 24s
# Epoch 4/59
# ----------
# LR 0.001
# train: jaccard: 0.859682, bce: 0.017644, dice: 0.784921, loss: 0.401283
# val: jaccard: 0.814695, bce: 0.015830, dice: 0.766562, loss: 0.391196
# saving best model
# 0m 30s
# Epoch 5/59
# ----------
# LR 0.001
# train: jaccard: 0.827403, bce: 0.017183, dice: 0.755238, loss: 0.386211
# val: jaccard: 0.805043, bce: 0.016348, dice: 0.730446, loss: 0.373397
# saving best model
# 0m 31s
# Epoch 6/59
# ----------
# LR 0.001
# train: jaccard: 0.796281, bce: 0.019845, dice: 0.714733, loss: 0.367289
# val: jaccard: 0.757476, bce: 0.022165, dice: 0.684638, loss: 0.353402
# saving best model
# 0m 30s
# Epoch 7/59
# ----------
# LR 0.001
# train: jaccard: 0.740640, bce: 0.026750, dice: 0.658628, loss: 0.342689
# val: jaccard: 0.732123, bce: 0.026614, dice: 0.621867, loss: 0.324240
# saving best model
# 0m 30s
# Epoch 8/59
# ----------
# LR 0.001
# train: jaccard: 0.720400, bce: 0.029169, dice: 0.601595, loss: 0.315382
# val: jaccard: 0.692091, bce: 0.021107, dice: 0.568811, loss: 0.294959
# saving best model
# 0m 29s
# Epoch 9/59
# ----------
# LR 0.001
# train: jaccard: 0.683944, bce: 0.021962, dice: 0.556428, loss: 0.289195
# val: jaccard: 0.661581, bce: 0.023229, dice: 0.517758, loss: 0.270494
# saving best model
# 0m 30s
# Epoch 10/59
# ----------
# LR 0.001
# train: jaccard: 0.638990, bce: 0.024498, dice: 0.485018, loss: 0.254758
# val: jaccard: 0.576125, bce: 0.017925, dice: 0.437115, loss: 0.227520
# saving best model
# 0m 30s
# Epoch 11/59
# ----------
# LR 0.001
# train: jaccard: 0.561875, bce: 0.018505, dice: 0.425810, loss: 0.222157
# val: jaccard: 0.565359, bce: 0.024774, dice: 0.394117, loss: 0.209445
# saving best model
# 0m 30s
# Epoch 12/59
# ----------
# LR 0.001
# train: jaccard: 0.559624, bce: 0.027051, dice: 0.397010, loss: 0.212031
# val: jaccard: 0.564500, bce: 0.024835, dice: 0.386426, loss: 0.205630
# saving best model
# 0m 31s
# Epoch 13/59
# ----------
# LR 0.001
# train: jaccard: 0.544556, bce: 0.021990, dice: 0.375564, loss: 0.198777
# val: jaccard: 0.548627, bce: 0.019691, dice: 0.378241, loss: 0.198966
# saving best model
# 0m 30s
# Epoch 14/59
# ----------
# LR 0.001
# train: jaccard: 0.536949, bce: 0.017455, dice: 0.364463, loss: 0.190959
# val: jaccard: 0.528398, bce: 0.018953, dice: 0.361128, loss: 0.190040
# saving best model
# 0m 31s
# Epoch 15/59
# ----------
# LR 0.001
# train: jaccard: 0.532903, bce: 0.020436, dice: 0.351005, loss: 0.185721
# val: jaccard: 0.532289, bce: 0.018198, dice: 0.358545, loss: 0.188372
# saving best model
# 0m 29s
# Epoch 16/59
# ----------
# LR 0.001
# train: jaccard: 0.516233, bce: 0.016183, dice: 0.341769, loss: 0.178976
# val: jaccard: 0.515146, bce: 0.014899, dice: 0.346503, loss: 0.180701
# saving best model
# 0m 30s
# Epoch 17/59
# ----------
# LR 0.001
# train: jaccard: 0.505662, bce: 0.016852, dice: 0.329915, loss: 0.173384
# val: jaccard: 0.522430, bce: 0.017634, dice: 0.331883, loss: 0.174758
# saving best model
# 0m 30s
# Epoch 18/59
# ----------
# LR 0.001
# train: jaccard: 0.495672, bce: 0.015211, dice: 0.319807, loss: 0.167509
# val: jaccard: 0.479905, bce: 0.011606, dice: 0.318940, loss: 0.165273
# saving best model
# 0m 30s
# Epoch 19/59
# ----------
# LR 0.001
# train: jaccard: 0.467798, bce: 0.013168, dice: 0.310402, loss: 0.161785
# val: jaccard: 0.483880, bce: 0.019917, dice: 0.304568, loss: 0.162242
# saving best model
# 0m 30s
# Epoch 20/59
# ----------
# LR 0.001
# train: jaccard: 0.474602, bce: 0.018392, dice: 0.298135, loss: 0.158263
# val: jaccard: 0.476454, bce: 0.012975, dice: 0.304603, loss: 0.158789
# saving best model
# 0m 30s
# Epoch 21/59
# ----------
# LR 0.001
# train: jaccard: 0.467015, bce: 0.013984, dice: 0.304761, loss: 0.159373
# val: jaccard: 0.444011, bce: 0.012992, dice: 0.291992, loss: 0.152492
# saving best model
# 0m 32s
# Epoch 22/59
# ----------
# LR 0.001
# train: jaccard: 0.437250, bce: 0.013872, dice: 0.287077, loss: 0.150474
# val: jaccard: 0.452191, bce: 0.016456, dice: 0.275418, loss: 0.145937
# saving best model
# 0m 30s
# Epoch 23/59
# ----------
# LR 0.001
# train: jaccard: 0.421465, bce: 0.013379, dice: 0.268220, loss: 0.140800
# val: jaccard: 0.462755, bce: 0.015541, dice: 0.291597, loss: 0.153569
# 0m 31s
# Epoch 24/59
# ----------
# LR 0.001
# train: jaccard: 0.397491, bce: 0.012783, dice: 0.256921, loss: 0.134852
# val: jaccard: 0.424457, bce: 0.016795, dice: 0.253791, loss: 0.135293
# saving best model
# 0m 30s
# Epoch 25/59
# ----------
# LR 0.001
# train: jaccard: 0.369203, bce: 0.013159, dice: 0.231464, loss: 0.122312
# val: jaccard: 0.352808, bce: 0.014751, dice: 0.212984, loss: 0.113868
# saving best model
# 0m 30s
# Epoch 26/59
# ----------
# LR 0.001
# train: jaccard: 0.343800, bce: 0.014086, dice: 0.214466, loss: 0.114276
# val: jaccard: 0.334706, bce: 0.012316, dice: 0.207552, loss: 0.109934
# saving best model
# 0m 30s
# Epoch 27/59
# ----------
# LR 0.001
# train: jaccard: 0.320847, bce: 0.013152, dice: 0.192381, loss: 0.102767
# val: jaccard: 0.335376, bce: 0.013294, dice: 0.204264, loss: 0.108779
# saving best model
# 0m 30s
# Epoch 28/59
# ----------
# LR 0.001
# train: jaccard: 0.317701, bce: 0.010838, dice: 0.188542, loss: 0.099690
# val: jaccard: 0.324145, bce: 0.009926, dice: 0.197377, loss: 0.103651
# saving best model
# 0m 29s
# Epoch 29/59
# ----------
# LR 0.0001
# train: jaccard: 0.309038, bce: 0.009244, dice: 0.184490, loss: 0.096867
# val: jaccard: 0.324826, bce: 0.009895, dice: 0.191408, loss: 0.100651
# saving best model
# 0m 29s
# Epoch 30/59
# ----------
# LR 0.0001
# train: jaccard: 0.310036, bce: 0.009309, dice: 0.181156, loss: 0.095233
# val: jaccard: 0.324439, bce: 0.009987, dice: 0.191603, loss: 0.100795
# 0m 31s
# Epoch 31/59
# ----------
# LR 0.0001
# train: jaccard: 0.309906, bce: 0.009353, dice: 0.180556, loss: 0.094955
# val: jaccard: 0.324036, bce: 0.010041, dice: 0.190364, loss: 0.100202
# saving best model
# 0m 30s
# Epoch 32/59
# ----------
# LR 0.0001
# train: jaccard: 0.309257, bce: 0.009325, dice: 0.178934, loss: 0.094130
# val: jaccard: 0.321821, bce: 0.010018, dice: 0.190590, loss: 0.100304
# 0m 31s
# Epoch 33/59
# ----------
# LR 0.0001
# train: jaccard: 0.306691, bce: 0.009231, dice: 0.178622, loss: 0.093927
# val: jaccard: 0.320749, bce: 0.009896, dice: 0.190326, loss: 0.100111
# saving best model
# 0m 30s
# Epoch 34/59
# ----------
# LR 0.0001
# train: jaccard: 0.305865, bce: 0.009077, dice: 0.177781, loss: 0.093429
# val: jaccard: 0.321798, bce: 0.009764, dice: 0.189936, loss: 0.099850
# saving best model
# 0m 31s
# Epoch 35/59
# ----------
# LR 0.0001
# train: jaccard: 0.305602, bce: 0.009025, dice: 0.177114, loss: 0.093069
# val: jaccard: 0.321106, bce: 0.009767, dice: 0.189006, loss: 0.099387
# saving best model
# 0m 30s
# Epoch 36/59
# ----------
# LR 0.0001
# train: jaccard: 0.304756, bce: 0.009055, dice: 0.176079, loss: 0.092567
# val: jaccard: 0.320562, bce: 0.009758, dice: 0.188350, loss: 0.099054
# saving best model
# 0m 31s
# Epoch 37/59
# ----------
# LR 0.0001
# train: jaccard: 0.303243, bce: 0.008927, dice: 0.175518, loss: 0.092223
# val: jaccard: 0.319072, bce: 0.009542, dice: 0.188507, loss: 0.099025
# saving best model
# 0m 30s
# Epoch 38/59
# ----------
# LR 0.0001
# train: jaccard: 0.300559, bce: 0.008724, dice: 0.174714, loss: 0.091719
# val: jaccard: 0.318554, bce: 0.009460, dice: 0.188333, loss: 0.098896
# saving best model
# 0m 30s
# Epoch 39/59
# ----------
# LR 0.0001
# train: jaccard: 0.297980, bce: 0.008605, dice: 0.173959, loss: 0.091282
# val: jaccard: 0.318081, bce: 0.009405, dice: 0.188258, loss: 0.098831
# saving best model
# 0m 29s
# Epoch 40/59
# ----------
# LR 0.0001
# train: jaccard: 0.295805, bce: 0.008529, dice: 0.173222, loss: 0.090875
# val: jaccard: 0.317346, bce: 0.009317, dice: 0.188021, loss: 0.098669
# saving best model
# 0m 29s
# Epoch 41/59
# ----------
# LR 0.0001
# train: jaccard: 0.293714, bce: 0.008459, dice: 0.172066, loss: 0.090263
# val: jaccard: 0.316470, bce: 0.009281, dice: 0.187234, loss: 0.098258
# saving best model
# 0m 30s
# Epoch 42/59
# ----------
# LR 0.0001
# train: jaccard: 0.292717, bce: 0.008402, dice: 0.170970, loss: 0.089686
# val: jaccard: 0.315318, bce: 0.009162, dice: 0.186867, loss: 0.098014
# saving best model
# 0m 30s
# Epoch 43/59
# ----------
# LR 0.0001
# train: jaccard: 0.288578, bce: 0.008184, dice: 0.169599, loss: 0.088892
# val: jaccard: 0.313464, bce: 0.008958, dice: 0.186546, loss: 0.097752
# saving best model
# 0m 30s
# Epoch 44/59
# ----------
# LR 0.0001
# train: jaccard: 0.282271, bce: 0.007855, dice: 0.168020, loss: 0.087937
# val: jaccard: 0.308160, bce: 0.008682, dice: 0.186501, loss: 0.097592
# saving best model
# 0m 29s
# Epoch 45/59
# ----------
# LR 0.0001
# train: jaccard: 0.274740, bce: 0.007568, dice: 0.165450, loss: 0.086509
# val: jaccard: 0.303874, bce: 0.008480, dice: 0.183950, loss: 0.096215
# saving best model
# 0m 30s
# Epoch 46/59
# ----------
# LR 0.0001
# train: jaccard: 0.264803, bce: 0.007272, dice: 0.161590, loss: 0.084431
# val: jaccard: 0.292186, bce: 0.008263, dice: 0.181868, loss: 0.095065
# saving best model
# 0m 29s
# Epoch 47/59
# ----------
# LR 0.0001
# train: jaccard: 0.254085, bce: 0.006951, dice: 0.157656, loss: 0.082304
# val: jaccard: 0.282866, bce: 0.008088, dice: 0.177438, loss: 0.092763
# saving best model
# 0m 29s
# Epoch 48/59
# ----------
# LR 0.0001
# train: jaccard: 0.248504, bce: 0.006718, dice: 0.152376, loss: 0.079547
# val: jaccard: 0.276888, bce: 0.008016, dice: 0.172879, loss: 0.090447
# saving best model
# 0m 30s
# Epoch 49/59
# ----------
# LR 0.0001
# train: jaccard: 0.239526, bce: 0.006511, dice: 0.146955, loss: 0.076733
# val: jaccard: 0.262407, bce: 0.007927, dice: 0.167765, loss: 0.087846
# saving best model
# 0m 30s
# Epoch 50/59
# ----------
# LR 0.0001
# train: jaccard: 0.229079, bce: 0.006323, dice: 0.141763, loss: 0.074043
# val: jaccard: 0.249035, bce: 0.007861, dice: 0.162222, loss: 0.085041
# saving best model
# 0m 30s
# Epoch 51/59
# ----------
# LR 0.0001
# train: jaccard: 0.216613, bce: 0.005952, dice: 0.134699, loss: 0.070325
# val: jaccard: 0.239814, bce: 0.007809, dice: 0.156531, loss: 0.082170
# saving best model
# 0m 29s
# Epoch 52/59
# ----------
# LR 0.0001
# train: jaccard: 0.203976, bce: 0.005623, dice: 0.128921, loss: 0.067272
# val: jaccard: 0.219744, bce: 0.007489, dice: 0.149723, loss: 0.078606
# saving best model
# 0m 28s
# Epoch 53/59
# ----------
# LR 0.0001
# train: jaccard: 0.192414, bce: 0.005371, dice: 0.121372, loss: 0.063372
# val: jaccard: 0.208607, bce: 0.007369, dice: 0.148123, loss: 0.077746
# saving best model
# 0m 29s
# Epoch 54/59
# ----------
# LR 0.0001
# train: jaccard: 0.175756, bce: 0.005073, dice: 0.114628, loss: 0.059850
# val: jaccard: 0.180385, bce: 0.007474, dice: 0.135215, loss: 0.071345
# saving best model
# 0m 29s
# Epoch 55/59
# ----------
# LR 0.0001
# train: jaccard: 0.151542, bce: 0.004729, dice: 0.104786, loss: 0.054757
# val: jaccard: 0.163523, bce: 0.007506, dice: 0.128101, loss: 0.067804
# saving best model
# 0m 28s
# Epoch 56/59
# ----------
# LR 0.0001
# train: jaccard: 0.136233, bce: 0.004566, dice: 0.096763, loss: 0.050665
# val: jaccard: 0.151117, bce: 0.007480, dice: 0.120262, loss: 0.063871
# saving best model
# 0m 29s
# Epoch 57/59
# ----------
# LR 0.0001
# train: jaccard: 0.125351, bce: 0.004470, dice: 0.088421, loss: 0.046445
# val: jaccard: 0.140754, bce: 0.007384, dice: 0.115474, loss: 0.061429
# saving best model
# 0m 29s
# Epoch 58/59
# ----------
# LR 0.0001
# train: jaccard: 0.117141, bce: 0.004407, dice: 0.082622, loss: 0.043515
# val: jaccard: 0.136146, bce: 0.007933, dice: 0.110352, loss: 0.059143
# saving best model
# 0m 30s
# Epoch 59/59
# ----------
# LR 1e-05
# train: jaccard: 0.111819, bce: 0.004383, dice: 0.077858, loss: 0.041120
# val: jaccard: 0.131374, bce: 0.007792, dice: 0.107789, loss: 0.057791
# saving best model
# 0m 28s
# Best val loss: 0.057791
# test: jaccard: 0.050942, bce: 0.001425, dice: 0.030586, loss: 0.016005
# (3, 6, 192, 192)

# %%
utilities.run(UNet,epochs=100)
# Out:
# Epoch 0/99
# ----------
# LR 0.001
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# train: jaccard: 0.986026, bce: 0.569051, dice: 0.990011, loss: 0.779531
# val: jaccard: 1.000000, bce: 0.076361, dice: 0.994673, loss: 0.535517
# saving best model
# 0m 27s
# Epoch 1/99
# ----------
# LR 0.001
# train: jaccard: 1.000000, bce: 0.060016, dice: 0.985705, loss: 0.522860
# val: jaccard: 1.000000, bce: 0.021608, dice: 0.911052, loss: 0.466330
# saving best model
# 0m 21s
# Epoch 2/99
# ----------
# LR 0.001
# train: jaccard: 0.969761, bce: 0.020674, dice: 0.861083, loss: 0.440879
# val: jaccard: 0.899010, bce: 0.016851, dice: 0.806096, loss: 0.411473
# saving best model
# 0m 26s
# Epoch 3/99
# ----------
# LR 0.001
# train: jaccard: 0.842959, bce: 0.018876, dice: 0.797081, loss: 0.407979
# val: jaccard: 0.802267, bce: 0.017118, dice: 0.775680, loss: 0.396399
# saving best model
# 0m 30s
# Epoch 4/99
# ----------
# LR 0.001
# train: jaccard: 0.793189, bce: 0.019048, dice: 0.768245, loss: 0.393647
# val: jaccard: 0.787910, bce: 0.018129, dice: 0.749155, loss: 0.383642
# saving best model
# 0m 29s
# Epoch 5/99
# ----------
# LR 0.001
# train: jaccard: 0.788444, bce: 0.020824, dice: 0.736656, loss: 0.378740
# val: jaccard: 0.785664, bce: 0.021007, dice: 0.712420, loss: 0.366714
# saving best model
# 0m 30s
# Epoch 6/99
# ----------
# LR 0.001
# train: jaccard: 0.785659, bce: 0.025787, dice: 0.700573, loss: 0.363180
# val: jaccard: 0.785938, bce: 0.038188, dice: 0.694067, loss: 0.366128
# saving best model
# 0m 29s
# Epoch 7/99
# ----------
# LR 0.001
# train: jaccard: 0.780631, bce: 0.030282, dice: 0.676031, loss: 0.353156
# val: jaccard: 0.749474, bce: 0.022494, dice: 0.652451, loss: 0.337473
# saving best model
# 0m 29s
# Epoch 8/99
# ----------
# LR 0.001
# train: jaccard: 0.729426, bce: 0.023938, dice: 0.635587, loss: 0.329763
# val: jaccard: 0.724323, bce: 0.022416, dice: 0.604504, loss: 0.313460
# saving best model
# 0m 29s
# Epoch 9/99
# ----------
# LR 0.001
# train: jaccard: 0.701394, bce: 0.024891, dice: 0.576456, loss: 0.300673
# val: jaccard: 0.647874, bce: 0.025538, dice: 0.519032, loss: 0.272285
# saving best model
# 0m 29s
# Epoch 10/99
# ----------
# LR 0.001
# train: jaccard: 0.619275, bce: 0.025294, dice: 0.481149, loss: 0.253221
# val: jaccard: 0.576677, bce: 0.015637, dice: 0.442842, loss: 0.229240
# saving best model
# 0m 30s
# Epoch 11/99
# ----------
# LR 0.001
# train: jaccard: 0.557141, bce: 0.029016, dice: 0.412531, loss: 0.220773
# val: jaccard: 0.564904, bce: 0.033653, dice: 0.396187, loss: 0.214920
# saving best model
# 0m 29s
# Epoch 12/99
# ----------
# LR 0.001
# train: jaccard: 0.538101, bce: 0.024197, dice: 0.393512, loss: 0.208854
# val: jaccard: 0.552667, bce: 0.031863, dice: 0.381076, loss: 0.206469
# saving best model
# 0m 29s
# Epoch 13/99
# ----------
# LR 0.001
# train: jaccard: 0.541397, bce: 0.034208, dice: 0.371159, loss: 0.202684
# val: jaccard: 0.558770, bce: 0.027503, dice: 0.382189, loss: 0.204846
# saving best model
# 0m 29s
# Epoch 14/99
# ----------
# LR 0.001
# train: jaccard: 0.543227, bce: 0.027766, dice: 0.368127, loss: 0.197946
# val: jaccard: 0.545902, bce: 0.024410, dice: 0.363517, loss: 0.193963
# saving best model
# 0m 29s
# Epoch 15/99
# ----------
# LR 0.001
# train: jaccard: 0.523584, bce: 0.019867, dice: 0.357211, loss: 0.188539
# val: jaccard: 0.526714, bce: 0.021963, dice: 0.352795, loss: 0.187379
# saving best model
# 0m 29s
# Epoch 16/99
# ----------
# LR 0.001
# train: jaccard: 0.512943, bce: 0.022317, dice: 0.344533, loss: 0.183425
# val: jaccard: 0.507612, bce: 0.018577, dice: 0.342356, loss: 0.180466
# saving best model
# 0m 29s
# Epoch 17/99
# ----------
# LR 0.001
# train: jaccard: 0.496316, bce: 0.017348, dice: 0.338259, loss: 0.177803
# val: jaccard: 0.510370, bce: 0.016877, dice: 0.339096, loss: 0.177987
# saving best model
# 0m 29s
# Epoch 18/99
# ----------
# LR 0.001
# train: jaccard: 0.495865, bce: 0.015515, dice: 0.333186, loss: 0.174351
# val: jaccard: 0.483869, bce: 0.012631, dice: 0.326821, loss: 0.169726
# saving best model
# 0m 30s
# Epoch 19/99
# ----------
# LR 0.001
# train: jaccard: 0.468481, bce: 0.013152, dice: 0.317180, loss: 0.165166
# val: jaccard: 0.455038, bce: 0.012649, dice: 0.309364, loss: 0.161006
# saving best model
# 0m 29s
# Epoch 20/99
# ----------
# LR 0.001
# train: jaccard: 0.458878, bce: 0.014526, dice: 0.307480, loss: 0.161003
# val: jaccard: 0.450077, bce: 0.013546, dice: 0.295186, loss: 0.154366
# saving best model
# 0m 30s
# Epoch 21/99
# ----------
# LR 0.001
# train: jaccard: 0.447512, bce: 0.015180, dice: 0.298386, loss: 0.156783
# val: jaccard: 0.423121, bce: 0.013310, dice: 0.277137, loss: 0.145224
# saving best model
# 0m 28s
# Epoch 22/99
# ----------
# LR 0.001
# train: jaccard: 0.410828, bce: 0.012840, dice: 0.267734, loss: 0.140287
# val: jaccard: 0.380021, bce: 0.009989, dice: 0.258884, loss: 0.134436
# saving best model
# 0m 29s
# Epoch 23/99
# ----------
# LR 0.001
# train: jaccard: 0.374073, bce: 0.011494, dice: 0.243253, loss: 0.127374
# val: jaccard: 0.361826, bce: 0.011657, dice: 0.222424, loss: 0.117041
# saving best model
# 0m 30s
# Epoch 24/99
# ----------
# LR 0.001
# train: jaccard: 0.369536, bce: 0.012886, dice: 0.234556, loss: 0.123721
# val: jaccard: 0.338236, bce: 0.011591, dice: 0.207792, loss: 0.109691
# saving best model
# 0m 30s
# Epoch 25/99
# ----------
# LR 0.001
# train: jaccard: 0.362593, bce: 0.014005, dice: 0.224778, loss: 0.119392
# val: jaccard: 0.384204, bce: 0.013848, dice: 0.231951, loss: 0.122900
# 0m 31s
# Epoch 26/99
# ----------
# LR 0.001
# train: jaccard: 0.355765, bce: 0.011842, dice: 0.222239, loss: 0.117041
# val: jaccard: 0.334159, bce: 0.009673, dice: 0.200650, loss: 0.105161
# saving best model
# 0m 29s
# Epoch 27/99
# ----------
# LR 0.001
# train: jaccard: 0.341896, bce: 0.011576, dice: 0.202798, loss: 0.107187
# val: jaccard: 0.344007, bce: 0.011103, dice: 0.201451, loss: 0.106277
# 0m 30s
# Epoch 28/99
# ----------
# LR 0.001
# train: jaccard: 0.324073, bce: 0.010405, dice: 0.195080, loss: 0.102742
# val: jaccard: 0.326974, bce: 0.009644, dice: 0.192665, loss: 0.101155
# saving best model
# 0m 30s
# Epoch 29/99
# ----------
# LR 0.0001
# train: jaccard: 0.319904, bce: 0.010280, dice: 0.187105, loss: 0.098692
# val: jaccard: 0.329442, bce: 0.009744, dice: 0.193687, loss: 0.101716
# 0m 30s
# Epoch 30/99
# ----------
# LR 0.0001
# train: jaccard: 0.320219, bce: 0.010318, dice: 0.186910, loss: 0.098614
# val: jaccard: 0.327340, bce: 0.009642, dice: 0.192262, loss: 0.100952
# saving best model
# 0m 30s
# Epoch 31/99
# ----------
# LR 0.0001
# train: jaccard: 0.317223, bce: 0.010060, dice: 0.184931, loss: 0.097496
# val: jaccard: 0.321887, bce: 0.009375, dice: 0.190043, loss: 0.099709
# saving best model
# 0m 29s
# Epoch 32/99
# ----------
# LR 0.0001
# train: jaccard: 0.311215, bce: 0.009617, dice: 0.183088, loss: 0.096353
# val: jaccard: 0.319371, bce: 0.009109, dice: 0.190585, loss: 0.099847
# 0m 30s
# Epoch 33/99
# ----------
# LR 0.0001
# train: jaccard: 0.308358, bce: 0.009341, dice: 0.183218, loss: 0.096280
# val: jaccard: 0.319542, bce: 0.009193, dice: 0.190500, loss: 0.099846
# 0m 30s
# Epoch 34/99
# ----------
# LR 0.0001
# train: jaccard: 0.308122, bce: 0.009578, dice: 0.181278, loss: 0.095428
# val: jaccard: 0.320239, bce: 0.009511, dice: 0.188648, loss: 0.099080
# saving best model
# 0m 31s
# Epoch 35/99
# ----------
# LR 0.0001
# train: jaccard: 0.310885, bce: 0.009946, dice: 0.180554, loss: 0.095250
# val: jaccard: 0.321325, bce: 0.009649, dice: 0.188511, loss: 0.099080
# 0m 30s
# Epoch 36/99
# ----------
# LR 0.0001
# train: jaccard: 0.310643, bce: 0.009974, dice: 0.180153, loss: 0.095063
# val: jaccard: 0.319964, bce: 0.009466, dice: 0.188114, loss: 0.098790
# saving best model
# 0m 30s
# Epoch 37/99
# ----------
# LR 0.0001
# train: jaccard: 0.308014, bce: 0.009656, dice: 0.179376, loss: 0.094516
# val: jaccard: 0.318415, bce: 0.009216, dice: 0.188650, loss: 0.098933
# 0m 30s
# Epoch 38/99
# ----------
# LR 0.0001
# train: jaccard: 0.305579, bce: 0.009388, dice: 0.179520, loss: 0.094454
# val: jaccard: 0.318440, bce: 0.009173, dice: 0.189274, loss: 0.099224
# 0m 30s
# Epoch 39/99
# ----------
# LR 0.0001
# train: jaccard: 0.306117, bce: 0.009489, dice: 0.178787, loss: 0.094138
# val: jaccard: 0.318938, bce: 0.009361, dice: 0.187973, loss: 0.098667
# saving best model
# 0m 31s
# Epoch 40/99
# ----------
# LR 0.0001
# train: jaccard: 0.306764, bce: 0.009670, dice: 0.177964, loss: 0.093817
# val: jaccard: 0.319162, bce: 0.009420, dice: 0.187838, loss: 0.098629
# saving best model
# 0m 30s
# Epoch 41/99
# ----------
# LR 0.0001
# train: jaccard: 0.305907, bce: 0.009652, dice: 0.177429, loss: 0.093541
# val: jaccard: 0.318645, bce: 0.009338, dice: 0.188212, loss: 0.098775
# 0m 31s
# Epoch 42/99
# ----------
# LR 0.0001
# train: jaccard: 0.304550, bce: 0.009502, dice: 0.176904, loss: 0.093203
# val: jaccard: 0.317837, bce: 0.009266, dice: 0.188330, loss: 0.098798
# 0m 30s
# Epoch 43/99
# ----------
# LR 0.0001
# train: jaccard: 0.303764, bce: 0.009448, dice: 0.176385, loss: 0.092916
# val: jaccard: 0.317472, bce: 0.009302, dice: 0.187625, loss: 0.098463
# saving best model
# 0m 31s
# Epoch 44/99
# ----------
# LR 0.0001
# train: jaccard: 0.303720, bce: 0.009452, dice: 0.175707, loss: 0.092579
# val: jaccard: 0.317004, bce: 0.009258, dice: 0.186571, loss: 0.097915
# saving best model
# 0m 30s
# Epoch 45/99
# ----------
# LR 0.0001
# train: jaccard: 0.302999, bce: 0.009381, dice: 0.175015, loss: 0.092198
# val: jaccard: 0.316423, bce: 0.009153, dice: 0.186509, loss: 0.097831
# saving best model
# 0m 31s
# Epoch 46/99
# ----------
# LR 0.0001
# train: jaccard: 0.301307, bce: 0.009240, dice: 0.174520, loss: 0.091880
# val: jaccard: 0.314999, bce: 0.009080, dice: 0.186309, loss: 0.097694
# saving best model
# 0m 30s
# Epoch 47/99
# ----------
# LR 0.0001
# train: jaccard: 0.300390, bce: 0.009182, dice: 0.173547, loss: 0.091365
# val: jaccard: 0.314200, bce: 0.009040, dice: 0.184248, loss: 0.096644
# saving best model
# 0m 30s
# Epoch 48/99
# ----------
# LR 0.0001
# train: jaccard: 0.300025, bce: 0.009163, dice: 0.172525, loss: 0.090844
# val: jaccard: 0.314429, bce: 0.008998, dice: 0.184513, loss: 0.096755
# 0m 30s
# Epoch 49/99
# ----------
# LR 0.0001
# train: jaccard: 0.299454, bce: 0.009017, dice: 0.171724, loss: 0.090371
# val: jaccard: 0.313792, bce: 0.008847, dice: 0.183532, loss: 0.096190
# saving best model
# 0m 31s
# Epoch 50/99
# ----------
# LR 0.0001
# train: jaccard: 0.296722, bce: 0.008815, dice: 0.169297, loss: 0.089056
# val: jaccard: 0.310686, bce: 0.008783, dice: 0.182552, loss: 0.095667
# saving best model
# 0m 30s
# Epoch 51/99
# ----------
# LR 0.0001
# train: jaccard: 0.293348, bce: 0.008687, dice: 0.165456, loss: 0.087071
# val: jaccard: 0.307412, bce: 0.008746, dice: 0.175898, loss: 0.092322
# saving best model
# 0m 31s
# Epoch 52/99
# ----------
# LR 0.0001
# train: jaccard: 0.293385, bce: 0.008851, dice: 0.162936, loss: 0.085894
# val: jaccard: 0.305728, bce: 0.008610, dice: 0.171752, loss: 0.090181
# saving best model
# 0m 30s
# Epoch 53/99
# ----------
# LR 0.0001
# train: jaccard: 0.290748, bce: 0.008517, dice: 0.158909, loss: 0.083713
# Epoch 81/99
# ----------
# LR 1e-05
# train: jaccard: 0.279173, bce: 0.007823, dice: 0.147212, loss: 0.077517
# val: jaccard: 0.296016, bce: 0.008021, dice: 0.163931, loss: 0.085976
# 0m 31s
# Epoch 82/99
# ----------
# LR 1e-05
# train: jaccard: 0.279277, bce: 0.007820, dice: 0.147111, loss: 0.077465
# val: jaccard: 0.296104, bce: 0.008024, dice: 0.163881, loss: 0.085953
# saving best model
# 0m 30s
# Epoch 83/99
# ----------
# LR 1e-05
# train: jaccard: 0.278863, bce: 0.007819, dice: 0.147033, loss: 0.077426
# val: jaccard: 0.296001, bce: 0.008023, dice: 0.163868, loss: 0.085945
# saving best model
# 0m 31s
# Epoch 84/99
# ----------
# LR 1e-05
# train: jaccard: 0.279057, bce: 0.007816, dice: 0.146947, loss: 0.077382
# val: jaccard: 0.295876, bce: 0.008023, dice: 0.163794, loss: 0.085908
# saving best model
# 0m 30s
# Epoch 85/99
# ----------
# LR 1e-05
# train: jaccard: 0.278772, bce: 0.007810, dice: 0.146864, loss: 0.077337
# val: jaccard: 0.295704, bce: 0.008018, dice: 0.163813, loss: 0.085916
# 0m 31s
# Epoch 86/99
# ----------
# LR 1e-05
# train: jaccard: 0.278361, bce: 0.007800, dice: 0.146768, loss: 0.077284
# val: jaccard: 0.295621, bce: 0.008015, dice: 0.163801, loss: 0.085908
# saving best model
# 0m 30s
# Epoch 87/99
# ----------
# LR 1e-05
# train: jaccard: 0.278297, bce: 0.007792, dice: 0.146689, loss: 0.077241
# val: jaccard: 0.295564, bce: 0.008017, dice: 0.163781, loss: 0.085899
# saving best model
# 0m 31s
# Epoch 88/99
# ----------
# LR 1e-05
# train: jaccard: 0.278227, bce: 0.007786, dice: 0.146595, loss: 0.077190
# val: jaccard: 0.295498, bce: 0.008015, dice: 0.163752, loss: 0.085883
# saving best model
# 0m 30s
# Epoch 89/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.278210, bce: 0.007781, dice: 0.146526, loss: 0.077153
# val: jaccard: 0.295498, bce: 0.008014, dice: 0.163746, loss: 0.085880
# saving best model
# 0m 31s
# Epoch 90/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.278103, bce: 0.007780, dice: 0.146516, loss: 0.077148
# val: jaccard: 0.295477, bce: 0.008014, dice: 0.163743, loss: 0.085878
# saving best model
# 0m 30s
# Epoch 91/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.278062, bce: 0.007779, dice: 0.146508, loss: 0.077144
# val: jaccard: 0.295486, bce: 0.008013, dice: 0.163741, loss: 0.085877
# saving best model
# 0m 31s
# Epoch 92/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.277987, bce: 0.007778, dice: 0.146499, loss: 0.077138
# val: jaccard: 0.295465, bce: 0.008012, dice: 0.163734, loss: 0.085873
# saving best model
# 0m 30s
# Epoch 93/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.278191, bce: 0.007777, dice: 0.146490, loss: 0.077133
# val: jaccard: 0.295444, bce: 0.008012, dice: 0.163729, loss: 0.085870
# saving best model
# 0m 31s
# Epoch 94/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.277910, bce: 0.007776, dice: 0.146480, loss: 0.077128
# val: jaccard: 0.295444, bce: 0.008012, dice: 0.163729, loss: 0.085870
# saving best model
# 0m 30s
# Epoch 95/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.277944, bce: 0.007775, dice: 0.146472, loss: 0.077124
# val: jaccard: 0.295444, bce: 0.008011, dice: 0.163729, loss: 0.085870
# saving best model
# 0m 29s
# Epoch 96/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.277652, bce: 0.007775, dice: 0.146462, loss: 0.077118
# val: jaccard: 0.295444, bce: 0.008011, dice: 0.163724, loss: 0.085868
# saving best model
# 0m 31s
# Epoch 97/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.278012, bce: 0.007775, dice: 0.146454, loss: 0.077115
# val: jaccard: 0.295424, bce: 0.008011, dice: 0.163715, loss: 0.085863
# saving best model
# 0m 31s
# Epoch 98/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.277980, bce: 0.007774, dice: 0.146444, loss: 0.077109
# val: jaccard: 0.295444, bce: 0.008010, dice: 0.163716, loss: 0.085863
# 0m 32s
# Epoch 99/99
# ----------
# LR 1.0000000000000002e-06
# train: jaccard: 0.277955, bce: 0.007773, dice: 0.146435, loss: 0.077104
# val: jaccard: 0.295424, bce: 0.008010, dice: 0.163710, loss: 0.085860
# saving best model
# 0m 31s
# Best val loss: 0.085860
# test: jaccard: 0.287138, bce: 0.007256, dice: 0.128906, loss: 0.068081
# (3, 6, 192, 192)

# %% [markdown]
# # hyper parameter tunning
#
# it seems that the best epochs is 60 and learning rate is 1e-3 and step size is 10 and gamma is 0.1

# %% [markdown]
# ### Grading Rubric (Total: 10 Marks)
#
# The lab is graded based on the following criteria:
#
# 1. **Data Loading and Preparation (1 Mark)**
#    - Ensure reproducible results by setting seed to `27` before all randomized operations. (1 Mark)
#
# 2. **U-Net Architecture (4 Marks)**
#    - Uses appropriate U-Net Architecture to the problem with a full pipeline. (4 Marks)
#
# 3. **Hyperparameters Tuning (2 Marks)**
#    - Report evaluation metrics on validation set. (1 Mark)
#    - Analyzes results and tunes hyperparameters. (1 Mark)
#
# 4. **Model Evaluation and Understanding (3 Marks)**
#    - Reports Jaccard Index and Dice Scores for test set. (1 Mark)
#    - **Comparison amongst your peers.** Compares the model's performance against those of peers to identify strengths and areas for improvement. (2 Marks)
#
# Each section of the lab will be evaluated on completeness, and correctness in approach and analysis. Part of the rubric also includes the student's ability to explain and justify their choices and results.

# %% [markdown]
# ## Submission Instructions
#
# To ensure a smooth evaluation process, please follow these steps for submitting your work:
#
# 1. **Prepare Your Submission:** Alongside your main notebook, include any additional files that are necessary for running the notebook successfully. This might include data files, images, or supplementary scripts.
#
# 2. **Rename Your Files:** Before submission, please rename your notebook to reflect the IDs of the two students working on this project. The format should be `ID1_ID2`, where `ID1` and `ID2` are the student IDs. For example, if the student IDs are `9123456` and `9876543`, then your notebook should be named `9123456_9876543.ipynb`.
#
# 3. **Check for Completeness:** Ensure that all required tasks are completed and that the notebook runs from start to finish without errors. This step is crucial for a smooth evaluation.
#
# 4. **Submit Your Work:** Once everything is in order, submit your notebook and any additional files via the designated submission link on Google Classroom **(code: 2yj6e24)**. Make sure you meet the submission deadline to avoid any late penalties.
# 5. Please, note that the same student should submit the assignments for the pair throughout the semester.
#
# By following these instructions carefully, you help us in evaluating your work efficiently and fairly **and any failure to adhere to these guidelines can affect your grades**. If you encounter any difficulties or have questions about the submission process, please reach out as soon as possible.
#
# We look forward to seeing your completed projects and wish you the best of luck!
